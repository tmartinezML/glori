# %%
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from pathlib import Path
from importlib import reload

os.chdir("..")  # Change root dir to project folder
print(os.getcwd())

from astropy.io import fits
from astropy.wcs import WCS
import utils.paths as paths


def get_image(file, get_wcs=True):
    hdul = fits.open(file)
    image = hdul[0].data
    if get_wcs:
        wcs = WCS(hdul[0].header, naxis=2)
        return image, wcs
    else:
        return image
# Out:
# /hs/fs08/data/group-brueggen/tmartinez/diffusion/src

# %%
import utils.paths as paths
import maps.map_maker

reload(maps.map_maker)
from maps.map_maker import MapMaker

reload(paths)
from astropy.table import Table

map_name = "map_5deg_v4"
ddf_parent = "ddf"


def load_trecs(map_name):
    f = paths.SKY_MAP_PARENT / map_name / f"trecs/catalogue_continuum_wrapped.fits"
    cat = Table.read(f, hdu=1, unit_parse_strict="silent").to_pandas()
    return cat

trecs_all = load_trecs(map_name)

comp_flag = (trecs_all["RadioClass"] < 6) | (trecs_all["size"] <= 1.5)
trecs_comp = trecs_all[comp_flag]

# %%
# Plot flux distributions
import numpy as np
from plotting.plot_utils import auto_log_bins

bins = auto_log_bins((trecs_all["I144"].values,), 100)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))

ax.hist(trecs_all["I144"], bins=bins, histtype="step", label="All")
ax.hist(trecs_comp["I144"], bins=bins, histtype="step", label="Compact")

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("Flux [mJy]")
ax.set_ylabel("Counts")
ax.grid(alpha=0.3)
ax.legend()

fig.show()

# %% [markdown]
# # Number of Sources Gaussian vs DM

# %% [markdown]
# # Verification Maps

# %%
import plotting.paper_plots_II
reload(plotting.paper_plots_II)
from plotting.paper_plots_II import map_catalog_histograms, residual_RMS, map_images

map_name = 'map_verif_v2'
kwargs = dict(map_name=map_name, output_dir=None)

map_catalog_histograms(**kwargs)
residual_RMS(**kwargs)
map_images(**kwargs)
# Out:
# Loading catalogs...
# Making plots...
# RMS of DDF residual: 7.55e-05 Jy/beam
# RMS in quadrants (micro-Jy/beam): Min = 4.26e+01, Max = 1.44e+02
# Using single norm for both maps
# /hs/fs08/data/group-brueggen/tmartinez/diffusion/src/plotting/paper_plots_II.py:436: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.savefig(output_dir / f"Map_Images_{cutout_size}deg.pdf")
# /hs/fs08/data/group-brueggen/tmartinez/diffusion/src/plotting/paper_plots_II.py:436: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.savefig(output_dir / f"Map_Images_{cutout_size}deg.pdf")

# %% [markdown]
# # Compare Model and LOFAR Map

# %%
import utils.paths as paths

map_name = "map_5deg_v5"

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"
image_file = map_folder / f"ddf/{map_name}.app.restored.fits"

# %%
from maps.map_maker import MapMaker

mm = MapMaker.load(map_name)
# Out:
# 14:29:17 - INFO (MapMaker): MapMaker initialized.
# 14:29:17 - WARNING (MapMaker): Changing file name map_5deg_v5 with map_5deg_v5.
# 14:29:17 - INFO (MapMaker): Reading MapMaker instance from
# 	/hs/fs08/data/group-brueggen/tmartinez/sky_maps/map_5deg_v5/map_5deg_v5.h5...
# 14:29:27 - INFO (MapMaker): MapMaker instance read.

# %%
len(mm.ext_df), len(mm.comp_df)
# Out:
# (12749, 196759)

# %% [markdown]
# ## With DDF:

# %%
import utils.paths as paths

map_name = "map_verif_v1"

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"
image_file = map_folder / f"ddf_nan-err/{map_name}.app.restored.fits"
# sky_model_file = map_folder / f"ddf/{map_name}.app.restored.fits"


data_arr, data_wcs = get_image(sky_model_file)
image_arr_prv, image_wcs_prv = get_image(image_file)

# %%
image_arr_prv.squeeze()
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype='>f4')

# %%
import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np

# %matplotlib widget
mpplt.double_map_plot(
    data_arr,
    image_arr_prv,
    wcs=(data_wcs, image_wcs_prv),
    size=(18, 9),
    norm_quantile=0.9975,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 import numpy as np
#       5 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 6 mpplt.double_map_plot(
#       7     data_arr,
#       8     image_arr_prv,
#       9     wcs=(data_wcs, image_wcs_prv),
#      10     size=(18, 9),
#      11     norm_quantile=0.9975,
#      12 )
#
# File /hs/fs08/data/group-brueggen/tmartinez/diffusion/src/plotting/map_plots.py:186, in double_map_plot(map1, map2, minmax, scale_fn, norm_quantile, wcs, size, fig_ax, norm, cbar_label, kw_map1, kw_map2)
#     177         return np.quantile(map[negative_flag], norm_quantile)
#     179     norm1 = Normalize(
#     180         vmin=get_vmin(map1),
#     181         vmax=np.quantile(map1[map1 > 0], norm_quantile),
#     182         clip=True,
#     183     )
#     184     norm2 = Normalize(
# ...

# %%
prv_map = "map_5deg_v4"
prv_resid_file = paths.SKY_MAP_PARENT / prv_map / f"ddf/{prv_map}.int.residual.fits"
prv_resid_arr, prv_resid_wcs = get_image(prv_resid_file)

# Plot ddf residual
ddf_resid_file = map_folder / f"ddf/{map_name}.int.residual.fits"
ddf_resid_arr, ddf_resid_wcs = get_image(ddf_resid_file)

# %matplotlib inline
mpplt.double_map_plot(
    prv_resid_arr,
    ddf_resid_arr,
    wcs=(prv_resid_wcs, ddf_resid_wcs),
    size=(18, 9),
    norm_quantile=0.9975,
)

# %%
cleaning_mask_file = map_folder / f"{map_name}_thresholdMask_5.00e-05JyBeam^-1_ddfSize.fits"
cleaning_mask_arr, cleaning_mask_wcs = get_image(cleaning_mask_file)

fig, ax, _ = mpplt.plot_sky_map(
    image_arr_prv,
    wcs=cleaning_mask_wcs,
    size=(12, 12),
    norm_quantile=0.9975,
)

ax.contour(
    cleaning_mask_arr.squeeze(),
    levels=[0.5],
    colors="red",
    alpha=0.3,
)

# %matplotlib widget
fig.show()

# %%
# Plot dirty image & residuals for every major cycle

import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np
from tqdm import tqdm

map_name = "map_verif_v1"
ddf_dir = paths.SKY_MAP_PARENT / map_name / "ddf"

residual_files = sorted(list(ddf_dir.glob("*.residual*.fits")))

# Add dirty image at the beginning
dirty_file = ddf_dir / f"{map_name}.dirty.fits"
residual_files = [dirty_file] + residual_files

# Determine figure rows and cols such that it is as quadratic as possible
n_plts = len(residual_files)
rows = int(np.sqrt(n_plts))
cols = int(np.ceil(n_plts / rows))

# Create figure
# %matplotlib inline
fig, axs = plt.subplots(rows, cols, figsize=(14, 14), constrained_layout=True)

for i, f in tqdm(enumerate(residual_files), total=len(residual_files)):
    
    arr, wcs = get_image(f)
    ax = axs.flat[i]

    
    im = ax.imshow(arr.squeeze(), origin="lower", cmap="inferno")
    ax.set_title(f.name.split(".")[-2])
    ax.axis('off')

# Remove axes for the rest of the plots
for ax in axs.flat[i+1:]:
    ax.axis('off')

fig.show()
# Out:
# 100%|██████████| 11/11 [00:15<00:00,  1.45s/it]

# %%
# Plot model images for every major cycle

# Plot dirty image & residuals for every major cycle

import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np
from tqdm import tqdm

map_name = "map_verif_v1"
ddf_dir = paths.SKY_MAP_PARENT / map_name / "ddf"

model_files = sorted(list(ddf_dir.glob("*.model*.fits")))

# Determine figure rows and cols such that it is as quadratic as possible
n_plts = len(residual_files)
rows = int(np.sqrt(n_plts))
cols = int(np.ceil(n_plts / rows))

# Create figure
# %matplotlib inline
fig, axs = plt.subplots(rows, cols, figsize=(14, 14), constrained_layout=True)

for i, f in tqdm(enumerate(model_files), total=len(residual_files)):
    
    arr, wcs = get_image(f)
    ax = axs.flat[i]

    im = ax.imshow(arr.squeeze(), origin="lower", cmap="inferno")
    ax.set_title(f"{f.name.split('.')[-2]}\nmax={arr.max():.2e} -- min={arr.min():.2e}")
    ax.axis('off')

# Remove axes for the rest of the plots
for ax in axs.flat[i+1:]:
    ax.axis('off')

fig.show()
# Out:
# 100%|██████████| 11/11 [00:09<00:00,  1.21it/s]
# /hs/fs08/data/group-brueggen/tmartinez/envs/cenv_diffusion/lib/python3.11/site-packages/matplotlib/image.py:484: RuntimeWarning: overflow encountered in subtract
#   A_scaled -= a_min
# /hs/fs08/data/group-brueggen/tmartinez/envs/cenv_diffusion/lib/python3.11/site-packages/matplotlib/image.py:485: RuntimeWarning: overflow encountered in subtract
#   vrange -= a_min
# /hs/fs08/data/group-brueggen/tmartinez/envs/cenv_diffusion/lib/python3.11/site-packages/matplotlib/image.py:505: RuntimeWarning: overflow encountered in multiply
#   A_resampled *= ((a_max - a_min) / frac)
# /hs/fs08/data/group-brueggen/tmartinez/envs/cenv_diffusion/lib/python3.11/site-packages/matplotlib/colors.py:1355: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)

# %%
reload(mpplt)

# Print differences between subsequent residuals
step_residuals = np.array([get_image(f)[0] for f in residual_files[1:]]).squeeze()

diffs = np.diff(step_residuals, axis=0)

# Determine figure rows and cols such that it is as quadratic as possible
n_plts = diffs.shape[0]
rows = int(np.sqrt(n_plts))
cols = int(np.ceil(n_plts / rows))

# Create figure
fig, axs = plt.subplots(rows, cols, figsize=(14, 4 * rows), constrained_layout=True)

for i, arr in enumerate(diffs):
    
    ax = axs.flat[i]
    absmax = max(
        -np.quantile(arr[arr < 0], 0.995),
        np.quantile(arr[arr > 0], 0.995)
    )
    
    _, ax, im = mpplt.plot_sky_map(
        arr,
        fig_ax=(fig, ax),
        norm_quantile=None,
        cbar=False,
        cmap='bwr',
        vmin=-absmax,
        vmax=absmax,
    )
    ax.set_title(f'Diff {i+2} - {i+1}')
    ax.axis('off')

# Remove axes for the rest of the plots
for ax in axs.flat[i+1:]:
    ax.axis('off')

# %matplotlib inline
fig.show()

# %%
# Compare int and app
map_name = "map_5deg_v4.1"
ddf_dir = paths.SKY_MAP_PARENT / map_name / "ddf"

int_arr = get_image(ddf_dir / f"{map_name}.int.restored.fits")[0].squeeze()
app_arr = get_image(ddf_dir / f"{map_name}.app.restored.fits")[0].squeeze()

ratio_arr = app_arr / int_arr

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

im = ax.imshow(ratio_arr, origin="lower", cmap="binary_r", vmin=0, vmax=2)
ax.axis('off')
# Secondary axis for cbar
cax = ax.inset_axes([1.02, 0, 0.05, 1])
fig.colorbar(im, cax=cax, label="$F_{app} / F_{int}$"),# fraction=0.046, pad=0.05)

fig.show()

# %% [markdown]
# ### Further experiments

# %%
in_model = data_arr.squeeze()

out_model, restored, residual = [
    get_image(map_folder / f"ddf/{map_name}.{key}.fits")[0].squeeze()
    for key in ["app.model", "app.restored", "residual05"]
]


def rms(arr, mask=None):
    if mask is not None:
        return np.sqrt(np.sum((arr * mask) ** 2) / np.sum(mask))
    return np.sqrt(np.mean(arr**2))

# %%
mpplt.double_map_plot(
    in_model,
    out_model,
    scale_fn=lambda x: x,  # np.clip(x, a_min=0, a_max=x.max()),
    size=(14, 7),
    minmax=False,
)

# %%
in_model.sum() / (out_model).sum()

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 7))

kwargs = {
    "bins": np.linspace(0, 1e-3, 100),
    "histtype": "step",
    "log": True,
}
ax.hist(in_model.flatten(), label="Input Model", **kwargs)
ax.hist(out_model.flatten(), label="Output Model", **kwargs)

ax.legend()
ax.grid(alpha=0.3)

# %% [markdown]
# #### Convolve input model with restoring beam

# %%
from scipy.signal import convolve, convolve2d
import numpy as np

# Zero-centered coordinate grid of same shape as input model.
# Cell size is 1.5 arcsec.
y, x = np.indices(in_model.shape).astype(float) * 1.5
y -= y.mean()
x -= x.mean()

# psf model
beam_size = 6.0  # FWHM in arcsec


def psf(x, y):
    sigma = beam_size / (2 * np.sqrt(2 * np.log(2)))
    return np.exp(-(x**2 + y**2) / (2 * sigma**2))


restoring_beam = psf(x, y)

conv_model = convolve(in_model, restoring_beam, mode="same")
conv_model.shape

# %%
mpplt.double_map_plot(
    in_model,
    conv_model,
    scale_fn=lambda x: x,  # np.clip(x, a_min=0, a_max=x.max()),
    size=(14, 7),
    minmax=False,
)

# %%
conv_model.sum() / in_model.sum()

# %%
model_ratio = (
    resize(restored, in_model.shape) - resize(residual, in_model.shape)
) / in_model
ratio_data = model_ratio[np.isfinite(model_ratio)].flatten()

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))

ax.hist(ratio_data, bins=np.linspace(-5, 5, 100), log=True, density=True)
ax.grid(alpha=0.3)
fig.show()

# %%
model_residual.max(), rms(restored, 1 - (out_model == 0)), rms(residual),

# %%
mpplt.double_map_plot(
    in_model * (1 - source_mask),
    residual,
    scale_fn=lambda x: x,  # np.clip(x, a_min=0, a_max=x.max()),
    minmax=False,
    size=(14, 7),
)

# %%
l = np.array([1, 2, 3, 4, 5])
N = lambda l: 45 * (l / 8) ** 2
N(l)

# %%
N(2.5)

# %%
data_arr.shape, image_arr_prv.shape

# %%
dist_mask, _ = get_image(
    map_folder / "map_1deg_max80_1e-7JyLimit_thresholdMask_1.00e-04JyPx^-1_ddfSize.fits"
)
dist_mask = dist_mask.squeeze()

# %%
import numpy as np

inv_mask = 1 - dist_mask
rms = np.sqrt(np.sum((image_arr_prv.squeeze() * inv_mask) ** 2) / inv_mask.sum())
rms

# %%
# Print model header
header = fits.getheader(image_file)
header

# %% [markdown]
# ## Model vs Mask:

# %%
map_name = "map_1deg_max80_1e-7JyLimit"

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"

# masks
mask_file = map_folder / f"{map_name}_thresholdMask_1.00e-04JyBeam^-1_ddfSize.fits"
# mask_file = map_folder / f"{map_name}_masked.fits"

data_arr, data_wcs = get_image(sky_model_file)
image_arr, image_wcs = get_image(mask_file)

# %%
import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np

# %matplotlib widget
mpplt.double_map_plot(
    data_arr,
    image_arr,
    wcs=(data_wcs, image_wcs),
    scale_fn = lambda x: x,
    size=(14, 7),
    minmax=True,
)

# %%
# Read header of image
from astropy.io import fits
from astropy.wcs import WCS

with fits.open(image_file) as hdul:
    header = hdul[0].header

header

# %% [markdown]
# ## LoTSS Map Comparison:

# %%
import utils.paths as paths
reload(paths)
import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np

lotss_file = paths.MOSAIC_DIR / "P202+42/mosaic-blanked.fits"
lotss_arr, lotss_wcs = get_image(lotss_file)

print(lotss_arr.shape)

# Center cutout of desired px, initially it is 9320 px
n_px = lotss_arr.shape[0]
N = lotss_arr.squeeze().shape[0]
n1 = (N - n_px) // 2
n2 = n1 + n_px
lotss_arr = lotss_arr[n1:n2, n1:n2]
lotss_wcs = lotss_wcs[n1:n2, n1:n2]
# lotss_arr = np.clip(lotss_arr, -0.0015, lotss_arr.max())

# %matplotlib widget
mpplt.plot_sky_map(
    lotss_arr, 
    wcs=lotss_wcs, 
    scale_fn=lambda x: x,
    size=(7, 7),
)

# %%
ratio = restored.sum() / lotss_arr.sum()

# %%
fig, axs = plt.subplots(2, 1, figsize=(7, 7))

kwargs = {
    #'bins': np.linspace(-0.001, 0.001, 100),
    "histtype": "step",
    "log": True,
}
max_bin = 0.0025
axs[0].hist(
    lotss_arr.flatten(), bins=np.linspace(0, max_bin, 100), label="LoTSS Map", **kwargs
)
axs[1].hist(
    restored.flatten(),
    bins=np.linspace(0, max_bin * ratio, 100),
    label="Simulated Map",
    **kwargs
)

for ax in axs:
    ax.legend()
    ax.grid(alpha=0.3)

# %% [markdown]
# Look at Dirty Image / PSF:

# %%
map_name_2 = "test_map_80"
map_folder_2 = paths.SKY_MAP_PARENT / map_name_2
sky_model_file_2 = map_folder_2 / f"{map_name_2}.fits"
image_file_2 = map_folder_2 / f"ddf/{map_name_2}_ddf.app.restored.fits"

model_arr_2, model_wcs_2 = get_image(sky_model_file_2)
image_arr_2, image_wcs_2 = get_image(image_file_2)

# %%
import plotting.map_plots as mpplt
reload(mpplt)

# file = map_folder / "ddf/test_map_80_ddf.dirty.fits"
file = '/hs/fs08/data/group-brueggen/tmartinez/sky_maps/test_map_80/ddf-pipeline/image_dirin_SSD_m.app.restored.fits'

dirty_arr, dirty_wcs = get_image(file)

# %matplotlib widget
mpplt.plot_sky_map(dirty_arr, wcs=dirty_wcs)

# %%
# map_name = 'map_1deg_max80'
map_name = "map_1deg_max80_1e-7JyLimit"

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"
# image_file = map_folder / "ddf-pipeline/image_full_ampphase_di_m.NS.app.restored.fits"
# sky_model_file = map_folder / "ddf_unscaled/map_2.5deg_max80.app.restored.fits"
image_file = map_folder / f"ddf/{map_name}.app.restored.fits"
# sky_model_file = map_folder / "ddf_noise/map_2.5deg_max80.app.restored.fits"
# sky_model_file = map_folder / "ddf-pipeline_unscaled/image_full_ampphase_m.app.restored.fits"
# sky_model_file = map_folder / "ddf-pipeline_ndir=10/image_full_ampphase_di_m.NS.app.restored.fits"
# image_file = map_folder / "ddf-pipeline/image_full_ampphase_m.app.restored.fits"
# image_file = map_folder / 'ddf-pipeline/image_dirin_SSD.app.restored.fits.mask.fits'

# masks
sky_model_file = map_folder / f"{map_name}_thresholdMask_1.00e-04JyBeam^-1.fits"

data_arr, data_wcs = get_image(sky_model_file)
image_arr, image_wcs = get_image(image_file)

# %%
import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np

# %matplotlib widget
mpplt.double_map_plot(
    data_arr,
    image_arr,
    wcs=(data_wcs, image_wcs),
    scale_fn = lambda x: x,
    size=(12, 6),
    minmax=False,
)

# %%
# Read header of image
from astropy.io import fits
from astropy.wcs import WCS

with fits.open(image_file) as hdul:
    header = hdul[0].header

header

# %%
import utils.paths as paths
reload(paths)
import plotting.map_plots as mpplt
reload(mpplt)
import numpy as np

lotss_file = paths.MOSAIC_DIR / "P202+42/mosaic-blanked.fits"
lotss_arr, lotss_wcs = get_image(lotss_file)

# Center cutout of desired px, initially it is 9320 px
n_px = 6075
N = lotss_arr.squeeze().shape[0]
n1 = (N - n_px) // 2
n2 = n1 + n_px
lotss_arr = lotss_arr[n1:n2, n1:n2]
lotss_wcs = lotss_wcs[n1:n2, n1:n2]
# lotss_arr = np.clip(lotss_arr, -0.0015, lotss_arr.max())

# %matplotlib widget
mpplt.plot_sky_map(
    lotss_arr, 
    wcs=lotss_wcs, 
    scale_fn=lambda x: x,
    size=(7, 7),
)

# %%
lotss_arr.shape

# %% [markdown]
# Look at Dirty Image / PSF:

# %%
import plotting.map_plots as mpplt
reload(mpplt)

# file = map_folder / "ddf/test_map_80_ddf.dirty.fits"
file = '/hs/fs08/data/group-brueggen/tmartinez/sky_maps/test_map_80/ddf-pipeline/image_dirin_SSD_m.app.restored.fits'

dirty_arr, dirty_wcs = get_image(file)

# %matplotlib widget
mpplt.plot_sky_map(dirty_arr, wcs=dirty_wcs)

# %% [markdown]
# # Source Visual Inspection

# %%
import maps.map_maker as map_maker

reload(map_maker)

map_name = "map_5deg_v3"

mm = map_maker.MapMaker.load(map_name)

# %%
masks = mm.ext_data["masks"]

# Look for mask that has pixels on edges
from data.segment import mask_edge, image_edge_mask

flag = np.array([m.sum() == 0 for m in masks])

# %%
from plotting.image_plots import random_image_grid, metric_peek

size = np.array(
    [max(s) if isinstance(s, tuple) else s for s in mm.comp_df["size"].values],
    dtype=float,
)

plt.hist(size, bins=100, log=True)

metric_peek(
    size,
    np.linspace(0, 50, 5),
    imgs,
)

# %%
import numpy as np

import maps.map_utils as mputil

reload(mputil)
import plotting.map_plots as mpplt

reload(mpplt)


def plot_extended_example(
    idx,
    mm,
    sky_model=True,
    obs_model=True,
    obs_parent="ddf",
    cutout_size=None,
    title=None,
):

    # Get information of extended source
    img = mm.ext_data["images"][idx]
    mask = mm.ext_data["masks"][idx]
    source_info = mm.ext_df.iloc[idx]
    centroid = int(source_info["centroid-1"]), int(source_info["centroid-0"])

    # Get cutout
    slices, _ = mputil.get_source_slice(
        (source_info["x_coord"], source_info["y_coord"]),
        img,
        mm.map_array,
        mm.map_size_deg,
        centroid=centroid,
        truncate_edge=False,
    )

    sky_model_cutout = mm.map_array[*slices]

    # Get observation model cutout
    obs_model = mm.out_dir / obs_parent / f"{mm.map_name}.int.restored.fits"
    obs_array = get_image(obs_model, get_wcs=False).squeeze()
    obs_slices, _ = mputil.get_source_slice(
        (source_info["x_coord"], source_info["y_coord"]),
        img,
        obs_array,
        mm.map_size_deg,
        centroid=centroid,
        truncate_edge=False,
    )
    obs_cutout = obs_array[*obs_slices]

    fig, axs = mpplt.plot_source_cutouts(
        img,
        title=title or f"Extended Source No. {i}",
        mask=mask,
        model_cutout=sky_model_cutout,
        sim_cutout=obs_cutout,
    )

    # Plot circle on first axis
    ax = axs[0]
    ax.add_artist(
        plt.Circle(
            (source_info["centroid-1"], source_info["centroid-0"]),
            source_info["feret_diameter_max"] / 2,
            fill=False,
            color="orange",
            linestyle="--",
            alpha=0.2,
        )
    )
    return fig, axs


n = 25
min_flux = 5e-3  # Jy

# Filter out sources with flux below threshold
df_filtered = mm.ext_df[mm.ext_df["flux"] > min_flux]

# Pick random idxs
idxs = np.random.choice(df_filtered.index, n)

# %matplotlib inline
ntot = len(mm.ext_df)
for i in [ntot-2, ntot-1]:
    fig, axs = plot_extended_example(
        i,
        mm,
        obs_parent="ddf",
        title=f"Extended Source No. {i} - Flux = {mm.ext_df.loc[i, 'flux']:.2e} Jy",
    )
    fig.show()

# %%
import numpy as np

import maps.map_utils as mputil

reload(mputil)
import plotting.map_plots as mpplt

reload(mpplt)


def plot_compact_example(
    idx,
    mm,
    sky_model=True,
    obs_model=True,
    obs_parent="ddf",
    cutout_size=None,
    title=None,
):

    # Get information of extended source
    img = mm.comp_images[idx]
    source_info = mm.comp_df.iloc[idx]

    # Get cutout
    slices, _ = mputil.get_source_slice(
        (source_info["x_coord"], source_info["y_coord"]),
        np.empty((cutout_size, cutout_size)),
        mm.map_array,
        mm.map_size_deg,
        truncate_edge=False,
    )

    sky_model_cutout = mm.map_array[*slices]

    # Get observation model cutout
    obs_model = mm.out_dir / obs_parent / f"{mm.map_name}.int.restored.fits"
    obs_array = get_image(obs_model, get_wcs=False).squeeze()
    obs_slices, _ = mputil.get_source_slice(
        (source_info["x_coord"], source_info["y_coord"]),
        np.empty((cutout_size, cutout_size)),
        obs_array,
        mm.map_size_deg,
        truncate_edge=False,
    )
    obs_cutout = obs_array[*obs_slices]

    fig, axs = mpplt.plot_source_cutouts(
        img,
        title=title or f"Extended Source No. {i}",
        model_cutout=sky_model_cutout,
        sim_cutout=obs_cutout,
    )
    return fig, axs


n = 25
min_size = 10

sizes = np.array(
    [
        max(size) if isinstance(size, tuple) else size
        for size in mm.comp_df["size"].values
    ]
)

# Filter out sources
df_filtered = mm.comp_df[sizes > min_size]

# Pick random idxs
# idxs = np.random.choice(df_filtered.index, n)

parse_size = lambda s: (
    f"({s[0]:.1f}, {s[1]:.1f})" if isinstance(s, tuple) else f"{s:.1f}"
)

for i in idxs:
    fig, axs = plot_compact_example(
        i,
        mm,
        title=f"Compact Source No. {i} - Size = {parse_size(mm.comp_df['size'].values[i])} as",
    )
    fig.show()
    break

# %%
import plotting.image_plots as imgp

imgp.random_image_grid(
    mm.comp_images,
    vmax=None,
)

# %% [markdown]
# # Compare Catalogs

# %%
import utils.paths as paths
import maps.map_maker

reload(maps.map_maker)
from maps.map_maker import MapMaker

reload(paths)
from astropy.table import Table

map_name = "map_5deg_v4.1"
ddf_parent = "ddf"

# Load source catalog to pandas
map_file = (
    paths.SKY_MAP_PARENT / map_name / ddf_parent / f"{map_name}.int.restored.fits"
)
map_cat_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / ddf_parent
    / f"{map_name}.int.restored_pybdsf"
    / f"catalogues/{map_name}.int.restored.pybdsf.srl.FITS"
)
map_cat = Table.read(map_cat_file).to_pandas()

# Load model catalog
model_file = paths.SKY_MAP_PARENT / map_name / f"{map_name}.fits"
model_cat_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / f"{map_name}.bdsfNoise_pybdsf"
    / f"catalogues/{map_name}.bdsfNoise.pybdsf.srl.FITS"
)
cat = Table.read(model_cat_file).to_pandas()

# Load TRECS catalog
trecs_file = paths.SKY_MAP_PARENT / map_name / f"trecs/catalogue_continuum_wrapped.fits"
trecs_cat = Table.read(trecs_file, hdu=1, unit_parse_strict="silent").to_pandas()

# Load lofar catalog
lofar_cat = Table.read(paths.LOTSS_DR2_CAT).to_pandas()

bdsf_catalog_dict = {
    "Sim. Map": map_cat,
    "LoTSS": lofar_cat,
    "Sky Model": cat,
}

colors_dict = {
    "Sim. Map": "tab:blue",
    "LoTSS": "tab:orange",
    "Sky Model": "tab:green",
}

# Load the map object tobe ale to plot example cutouts
from maps.map_maker import MapMaker

mm = MapMaker.load(map_name)
# Out:
# 13:42:36 - INFO (MapMaker): MapMaker initialized.
# 13:42:36 - WARNING (MapMaker): Changing file name map_5deg_v4.1 with map_5deg_v4.1.
# 13:42:36 - INFO (MapMaker): Reading MapMaker instance from
# 	/hs/fs08/data/group-brueggen/tmartinez/sky_maps/map_5deg_v4.1/map_5deg_v4.1.h5...
# 13:42:45 - INFO (MapMaker): MapMaker instance read.

# %% [markdown]
# ## Plot with Sources

# %%
# Plot map with scattered coordinates.
from tqdm import tqdm

model_or_map = 'model'

match model_or_map:
    case 'model':
        data_arr, data_wcs = get_image(model_file)
        cat = cat
    case 'map':
        data_arr, data_wcs = get_image(map_file)
        cat = map_cat
    case _:
        raise ValueError(f"Invalid value for model_or_map: {model_or_map}")

import matplotlib.pyplot as plt
import plotting.map_plots as mpplt
from astropy.coordinates import SkyCoord
import maps.map_utils as mputil
reload(mputil)
reload(mpplt)

# Plot map
# %matplotlib widget
fig, ax, _ = mpplt.plot_sky_map(data_arr, wcs=data_wcs)

# Plot PyBDSF sources
crd = SkyCoord(ra=cat["RA"], dec=cat["DEC"], unit="deg")
model_mask = cat['Total_flux'] < 1e-3
ax.scatter_coord(crd, s=0.1, color='red')

# Plot TRECS sources
x_px, y_px = mputil.coord2pix((trecs_cat["x_coord"], trecs_cat["y_coord"]), 5, data_wcs.array_shape)
ra_trecs, dec_trecs = data_wcs.array_index_to_world_values(x_px.values, y_px.values)
crd_trecs = SkyCoord(ra=ra_trecs, dec=dec_trecs, unit="deg")
ax.scatter_coord(crd_trecs, s=0.1, color='blue')

# Annotate extended sources
print('Annotating...')
x_px, y_px = mputil.coord2pix((mm.ext_df["x_coord"], mm.ext_df["y_coord"]), 5, data_wcs.array_shape)
ra_xt, dec_xt = data_wcs.array_index_to_world_values(x_px.values, y_px.values)
crd_xt = SkyCoord(ra=ra_xt, dec=dec_xt, unit="deg")
# ax.scatter_coord(crd_xt, s=1, color='red')
for i, _ in tqdm(mm.ext_df.iterrows(), total=len(mm.ext_df)):
    break
    ra, dec = ra_xt[i], dec_xt[i]
    # ax.annotate(f"{i} {ra},{dec}", (ra, dec), color='red', transform=ax.get_transform('world'))

fig.show()

# %%
from skimage.measure import regionprops_table

# %matplotlib inline
for i in [-2, -1]:
    plt.imshow(mm.ext_data['images'][i])
    plt.contour(dist_mask := mm.ext_data['masks'][i], levels=[0.5], colors='red')
    plt.show()
    print(regionprops_table(dist_mask, properties=("centroid", "feret_diameter_max")))

# %%
# Look for weird extended source
import astropy.units as u

weird_coord = SkyCoord("23h57m25s +23d48m")

# idx0, idx1, d2d, _ = weird_coord.search_around_sky(crd_trecs, 1 * u.arcmin)
flag = weird_coord.separation(crd_trecs) < 1 * u.arcmin

# %%
trecs_cat[flag]

# %%
mm_flag = [i in trecs_cat[flag].index for i in mm.comp_df["TRECS_index"]]
mm.comp_df[mm_flag]

# %%
import maps.map_utils

reload(maps.map_utils)
from maps.map_utils import gaussian_signal

img = gaussian_signal(size=(100, 20), angle=np.random.random() * 180)
print(img.shape)
plt.imshow(img)
plt.show()

# %%
5 * 4 / 2.355

# %%
# %matplotlib inline

for i in mm.comp_df[mm_flag].index:
    fig, axs = plot_compact_example(
        i,
        mm,
        obs_parent="ddf",
        title=f"Compact Source No. {i} - Flux = {mm.comp_df.loc[i, 'flux']:.2e} Jy",
        cutout_size=500,
    )
    fig.show()

# %%
# Plot doble map with scattered coordinates, showing PyBDSF noise.

# Load map:
map_file = paths.SKY_MAP_PARENT / map_name / f"{map_name}.fits"
map_arr, map_wcs = get_image(model_file)

# Add noise:
noise_scale = 1e-4 * 1e-3
z = np.random.normal(0, scale=noise_scale, size=map_arr.shape)
map_arr_noise = map_arr + z

import matplotlib.pyplot as plt
import plotting.map_plots as mpplt
from astropy.coordinates import SkyCoord
import maps.map_utils as mputil
reload(mputil)
reload(mpplt)

# Plot map
fig, axs = mpplt.double_map_plot(map_arr, map_arr_noise, wcs=map_wcs)

# Plot PyBDSF sources
crd = SkyCoord(ra=cat["RA"], dec=cat["DEC"], unit="deg")

[ax.scatter_coord(crd, s=0.1, color='red') for ax in axs]

# Plot TRECS sources
x_px, y_px = mputil.coord2pix((trecs_cat["x_coord"], trecs_cat["y_coord"]), 5, wcs.array_shape)
ra_trecs, dec_trecs = wcs.array_index_to_world_values(x_px.values, y_px.values)
crd_trecs = SkyCoord(ra=ra_trecs, dec=dec_trecs, unit="deg")
[ax.scatter_coord(crd_trecs, s=0.1, color='blue') for ax in axs]

# %matplotlib widget
fig.show()

# %% [markdown]
# ## Source Matching

# %%
# We need to get the conversion from pixel to deg
import maps.map_utils as mputil

with fits.open(paths.SKY_MAP_PARENT / map_name / f"{map_name}.fits") as hdul:
    wcs = WCS(hdul[0].header).dropaxis(-1)




# Convenience function for plotting
set_xmax = lambda ax, xmax: ax.set_xlim(-0.05 * xmax, xmax)
set_ymax = lambda ax, ymax: ax.set_ylim(-0.05 * ymax, ymax)


def get_unique_mask(idx, d2d):
    # For entries that have more than one appearance in idx, set flag to 1 only
    # for the closest source.
    idx_unique, counts = np.unique(idx, return_counts=True)
    mask = np.ones(len(idx), dtype=bool)
    for i, c in zip(idx_unique, counts):
        if c == 1:
            continue
        idx_c = np.where(idx == i)[0]
        idx_closest = np.argmin(d2d[idx_c])
        mask[idx_c] = False
        mask[idx_c[idx_closest]] = True

    return mask


def xy2radec(x, y):
    x_px, y_px = mputil.coord2pix(
        (x, y), wcs.wcs.cdelt[1] * wcs.array_shape[1], wcs.array_shape
    )
    ra, dec = wcs.array_index_to_world_values(x_px.values, y_px.values)
    return ra, dec


# Histogram normalized so total number of counts is 1
def norm_hist(data, bins):
    counts, _ = np.histogram(data, bins=bins)
    counts = counts / counts.sum()
    return counts, bins


def plot_norm_hist(ax, data, bins, hist_kwargs={}, **plot_kwargs):
    counts, _ = norm_hist(data, bins, **hist_kwargs)
    ax.stairs(counts, bins, **plot_kwargs)
# Out:
# WARNING: FITSFixedWarning: The WCS transformation has more axes (3) than the image it is associated with (2) [astropy.wcs.wcs]

# %%
# Load source coordinates into SkyCoord objects, which are then used for matching
from astropy.coordinates import SkyCoord

ra_trecs, dec_trecs = xy2radec(trecs_cat["x_coord"], trecs_cat["y_coord"])
crd_trecs = SkyCoord(ra=ra_trecs, dec=dec_trecs, unit="deg")

crd_map = SkyCoord(ra=map_cat["RA"], dec=map_cat["DEC"], unit="deg")
crd_model = SkyCoord(ra=cat["RA"], dec=cat["DEC"], unit="deg")

# %% [markdown]
# ### Model vs Map

# %%
# Match model cat and map cat
idx_model, d2d_model, d3d_model = crd_map.match_to_catalog_sky(crd_model)

# Selection Mask: Maximum distance & remove multiples & Maximum distance form center
dist_mask = d2d_model.arcsec < 5
unique_mask = get_unique_mask(idx_model, d2d_model)
center_coord = SkyCoord(ra=wcs.wcs.crval[0], dec=wcs.wcs.crval[1], unit="deg")
center_dist = center_coord.separation(crd_map).deg
center_dist_mask = center_dist < 2.5
total_mask = dist_mask * unique_mask * center_dist_mask


# Print detailed statistics with counts and fractions of map sources
n_map = len(map_cat)
n_total = total_mask.sum()
n_dist = dist_mask.sum()
n_unique = unique_mask.sum()
print(f"Total sources in map: {n_map:_}")
print(f"Sources within 5 arcsec: {n_dist:_} ({n_dist / n_map:.2%})")
print(
    f"Sources within 2.5 deg from center: {center_dist_mask.sum():_} ({center_dist_mask.sum() / n_map:.2%})"
)
print(f"Unique sources: {n_unique:_} ({n_unique / n_map:.2%})")
print(f"Total sources: {n_total:_} ({n_total / n_map:.2%})")


# Get Total Flux
f_map = map_cat["Total_flux"].values[total_mask] * 1e3
f_model = cat["Total_flux"].values[idx_model][total_mask] * 1e3
f_map_all = map_cat["Total_flux"].values * 1e3
f_model_all = cat["Total_flux"].values * 1e3

# Get peak flux
peak_map = map_cat["Peak_flux"].values[total_mask] * 1e3
peak_model = cat["Peak_flux"].values[idx_model][total_mask] * 1e3
peak_map_all = map_cat["Peak_flux"].values * 1e3
peak_model_all = cat["Peak_flux"].values * 1e3

# Get Size
maj_map = map_cat["Maj"].values[total_mask] * 3600
maj_model = cat["Maj"].values[idx_model][total_mask] * 3600
maj_map_all = map_cat["Maj"].values * 3600
maj_model_all = cat["Maj"].values * 3600

dc_maj_map = map_cat["DC_Maj"].values[total_mask] * 3600
dc_maj_model = cat["DC_Maj"].values[idx_model][total_mask] * 3600
dc_maj_map_all = map_cat["DC_Maj"].values * 3600
dc_maj_model_all = cat["DC_Maj"].values * 3600
# Out:
# Total sources in map: 23_187
# Sources within 5 arcsec: 19_978 (86.16%)
# Sources within 2.5 deg from center: 19_902 (85.83%)
# Unique sources: 21_652 (93.38%)
# Total sources: 17_192 (74.14%)

# %%
# Plot distance distribution for matches
import numpy as np

# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

counts, bins = np.histogram(d2d_model.arcsec, bins=np.linspace(0, 20, 100))
ax.stairs(np.cumsum(counts) / len(d2d_model), bins, fill=True, color="blue", alpha=0.5)
ax.set_xlabel("Distance [arcsec]")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)

fig.suptitle("Model Catalog vs. Map Catalog")
fig.show()

# %%
# Scatter plot in vs. out for different quantities: Total_flux, Peak_flux and 2xDC_Maj
fig, axs = plt.subplots(1, 3, figsize=(13, 4), constrained_layout=True)

# Exclude matches with too large distance
dist_mask = d2d_model.arcsec < 5

for ax, key in zip(axs, ["Total_flux", "Peak_flux", "DC_Maj"]):
    ax.scatter(
        cat[key].values[idx_model][dist_mask],
        map_cat[key].values[dist_mask],
        s=0.5,
        label=f"{key}",
    )
    # Plot 1:1 line
    ax.plot([0, 1], [0, 1], color="black", linestyle="--", alpha=0.25)
    ax.set_ylabel("Sim. Map")
    ax.set_xlabel("Sky Model")
    ax.legend()
    # ax.set_xscale("log")
    # ax.set_yscale("log")
    ax.grid(alpha=0.3)

set_xmax(axs[0], 0.2)
set_ymax(axs[0], 0.2)

set_xmax(axs[1], 0.05)
set_ymax(axs[1], 0.05)

set_xmax(axs[2], 0.01)
set_ymax(axs[2], 0.01)

fig.show()

# %%
# Log-log scatter plot for peak flux, with linear fit
fig, axs = plt.subplots(
    2, 1, figsize=(8, 10), constrained_layout=True, sharex=True, dpi=150
)

ax = axs[0]

# Plot data
ax.scatter(peak_model, peak_map, s=0.5, label="Peak Flux")

# Plot 1:1 line
ax.axline([1, 1], [10, 10], color="black", linestyle="--", alpha=0.25, label="1:1")

# Linear fit
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(peak_model, peak_map)
x = np.geomspace(0.1, 4e3, 100)
y = slope * x + intercept
ax.plot(
    x,
    y,
    color="red",
    linestyle="--",
    alpha=0.5,
    label=f"Fit: {slope:.2f}x + {intercept:.2f}",
)

ax.set_ylabel("Sim. Map")

lim = None
if lim is not None:
    ax.set_xlim(0 - 0.05 * lim, lim)
    ax.set_ylim(0 - 0.05 * lim, lim)

ax.set_yscale("log")

ax = axs[1]

# Plot ratio
ratio = peak_map / peak_model
ax.scatter(peak_model, ratio, s=0.5, label="Peak Flux Ratio")
ax.axhline(1, color="black", linestyle="--", alpha=0.25, label="1:1")
y = slope + intercept / x
ax.plot(
    x,
    y,
    color="red",
    linestyle="--",
    alpha=0.5,
    label=f"Fit: {slope:.2f} + {intercept:.2f}/x",
)
# ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_xlabel("Sky Model")

ymax = 2
ax.set_xlim(5e-2, 3e3)
ax.set_ylim(-0.05 * ymax, ymax)
ax.set_ylabel("Peak Flux Ratio")
ax.set_xscale("log")

for ax in axs:
    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
import plotting.map_stat_plots as msp

fig, ax, _ = msp.hist2D_plot(
    peak_model,
    ratio,
    nbins=100,
    xlim=(0.1, 2e2),
    ylim=(0, 2),
    log=(True, False),
    ax_labels=("Peak Flux [Jy]", "Peak Flux Ratio"),
    id_line=False,
    log_color=True,
)

# %%
# Scatter-Histogram Plot for Total Flux
import plotting.map_stat_plots as msp

reload(msp)

fig, axs, (xbins, ybins) = msp.scat_hist_plot(
    f_model,
    f_map,
    ax_labels=("Sky Model Flux (mJy)", "Sim. Map Flux (mJy)"),
    plt_label="Model-Map",
    xlim=(6e-2, 1e2),
    ylim=(1e-1, 1e2),
)

# Add histograms for all sources, to compare
axs[0][0].hist(f_model_all, bins=xbins, histtype="step", label="Model (All)")
axs[0][0].legend()
axs[1][1].hist(
    f_map_all, bins=ybins, histtype="step", orientation="horizontal", label="Map (All)"
)
axs[1][1].legend()


fig.show()

# %%
import plotting.map_stat_plots as msp

reload(msp)

fig, ax, (xbins, ybins) = msp.hist2D_plot(
    f_model,
    f_map,
    nbins=100,
    xlim=(0.1, 100),
    ylim=(0.1, 100),
    ax_labels=("Sky Model Flux (mJy)", "Sim. Map Flux (mJy)"),
)

# Plot fit result (see below)
ax.plot(xbins, xbins + 0.11, color="orange", linestyle="--", alpha=0.4)

# %%
# Offset distribution for different flux bins
fmin, fmax, n = 0.4, 10, 16
fbins = np.geomspace(fmin, fmax, n + 1)

# Find most compact nxm grid for n plots
nx = int(np.sqrt(n))
ny = int(np.ceil(n / nx))

fig, axs = plt.subplots(nx, ny, figsize=(3 * ny, 2 * nx), constrained_layout=True)

colors = plt.get_cmap("cool")(np.linspace(0, 1, n + 1))

for i in range(n):
    mn = fbins[i]
    mx = fbins[i + 1]
    mask = (f_model >= mn) & (f_model < mx)
    d_f = f_map[mask] - f_model[mask]

    axs.flatten()[i].hist(
        d_f,
        bins=np.linspace(-1, 2.5, 50),
        histtype="step",
        label=f"{mn:.2f}-{mx:.2f}",
        color=colors[i],
    )

for ax in axs.flatten():
    # ax.set_xscale('log')
    ax.set_yscale("log")

    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
# Offset Distribution
fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

f_offset = f_map - f_model

counts, bins, _ = ax.hist(
    f_offset,
    bins=np.linspace(-2.5, 2.5, 150),
    histtype="step",
    log=False,
    density=True,
    label="All",
)

# Fit amplitude-scaled gaussian
from scipy.optimize import curve_fit


def gaussian(x, a, mu, sigma):
    return a * np.exp(-((x - mu) ** 2) / (2 * sigma**2))


popt, pcov = curve_fit(gaussian, bins[:-1], counts, p0=[1, 0, 1])

x = np.linspace(-2.5, 2.5, 100)
ax.plot(
    x,
    gaussian(x, *popt),
    color="red",
    linestyle="--",
    alpha=0.3,
    label=f"Peak = {popt[1]:.2f}",
)

if False:
    flux_mask = f_model < 4
    ax.hist(
        f_offset[flux_mask],
        bins=np.linspace(-2.5, 2.5, 100),
        histtype="step",
        log=False,
        density=True,
        label="Flux < 4 mJy",
    )
    ax.hist(
        f_offset[~flux_mask],
        bins=np.linspace(-2.5, 2.5, 50),
        histtype="step",
        log=False,
        density=True,
        label="Flux >= 4 mJy",
    )


ax.set_xlabel("Map Flux - Model Flux (mJy)")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)
ax.legend()

fig.show()

# %%
# Include sources regardless of center distance
mask = dist_mask * unique_mask
f_offset = f_map_all[mask] - f_model_all[idx_model][mask]

delta_ra = (crd_map.ra.deg[mask] - center_coord.ra.deg - 180) % 360 - 180
delta_dec = (crd_map.dec.deg[mask] - center_coord.dec.deg - 180) % 360 - 180

# Plot flux offset over 2D Map
fig, ax = plt.subplots(1, 1, figsize=(8, 7), constrained_layout=True)

sc = ax.scatter(
    delta_ra,
    delta_dec,
    c=f_offset,
    s=1,
    cmap="coolwarm",
    vmin=-2.5,
    vmax=2.5,
)
ax.grid(alpha=0.3)
fig.colorbar(sc, ax=ax, label="Map Flux - Model Flux (mJy)")

fig.show()

import plotting.map_stat_plots as msp

reload(msp)

# Hist2D plot  plot center distance vs. flux offset
fig, ax, _ = msp.hist2D_plot(
    center_dist[mask],
    f_offset,
    nbins=100,
    xlim=(0, 3.25),
    ylim=(-1, 2),
    ax_labels=("Center Distance (deg)", "Flux Offset (mJy)"),
    log=(False, False),
    normalize="y",
    id_line=False,
    log_color=False,
)


# 2D Statistic: Map Position - Flux Offset
fig, ax, (xbins, ybins) = msp.stat2d_plot(
    delta_ra,
    delta_dec,
    f_offset,
    nbins=25,
    xlim=(-2.5, 2.5),
    ylim=(-2.5, 2.5),
    zlim=1,
    ax_labels=("RA Distance (deg)", "Dec Distance (deg)", "Flux Offset (mJy)"),
    log=(False, False, False),
    hist2d_kw=dict(log_color=True),
)

# %%
# Plot mean and variance of flux offset in center distance bins
distance_bins = np.linspace(0, 2.5 * np.sqrt(2), 11)  # * np.sqrt(2),
distance_bin = np.digitize(center_dist[mask], distance_bins)
binned_f_offset = [f_offset[distance_bin == i] for i in range(1, len(distance_bins))]

mean_f_offset = np.array([o.mean() for o in binned_f_offset])
median_f_offset = np.array([np.median(o) for o in binned_f_offset])
std_f_offset = np.array([o.std() for o in binned_f_offset])
one_sigma = np.array(
    [np.percentile(o, [50 - 68.26 / 2, 50 + 68.26 / 2]) for o in binned_f_offset]
)
two_sigma = np.array([np.percentile(o, [100 - 95.45, 95.45]) for o in binned_f_offset])
three_sigma = np.array(
    [np.percentile(o, [100 - 99.73, 99.73]) for o in binned_f_offset]
)

fig, axs = plt.subplots(
    2, 1, figsize=(7, 8), constrained_layout=True, sharex=True, dpi=150
)

ax = axs[0]
ax.errorbar(
    (distance_bins[:-1] + distance_bins[1:]) / 2,
    mean_f_offset,
    yerr=np.abs(one_sigma.T - mean_f_offset),
    fmt="_",
    label="Mean +/- 1$\sigma$",
)
ax.scatter(
    (distance_bins[:-1] + distance_bins[1:]) / 2,
    median_f_offset,
    label="Median",
    marker="x",
)
ax.set_ylabel("Flux Offset (mJy)")

ax = axs[1]
ax.hist(center_dist, bins=distance_bins, histtype="step", log=False)

ax.set_xlabel("Center Distance (deg)")
ax.set_ylabel("Count")

for ax in axs:
    ax.grid(alpha=0.3)
    ax.legend(loc="lower right")

fig.show()

# %%
# Flux and Size Histograms with LoTSS Data
fig, axs = plt.subplots(2, 1, figsize=(7, 9), constrained_layout=True, dpi=150)

ax = axs[0]
f_lofar = lofar_cat["Total_flux"].values
bins = np.logspace(-2, 5, 100)
# plot_norm_hist(ax, f_map, bins=bins, label="Map Flux (Matched)")
plot_norm_hist(ax, f_map_all, bins=bins, label="Map Flux (All)")
plot_norm_hist(ax, f_lofar, bins=bins, label="LoTSS Flux")
plot_norm_hist(ax, f_model, bins=bins, label="Model Flux (Matched)")
# plot_norm_hist(ax, f_model_all, bins=bins, label="Model Flux (All)")
ax.set_xlabel("Flux (mJy)")
ax.set_ylabel("Count")


ax = axs[1]
maj_lofar = lofar_cat["Maj"].values
bins = np.geomspace(3, 5e2, 100)
# plot_norm_hist(ax, maj_map, bins=bins, label="Map Maj (Matched)")
plot_norm_hist(ax, maj_map_all, bins=bins, label="Map Maj (All)")
plot_norm_hist(ax, maj_lofar, bins=bins, label="LoTSS Maj")
# plot_norm_hist(ax, maj_model, bins=bins, label="Model Maj (Matched)")
plot_norm_hist(ax, maj_model_all, bins=bins, label="Model Maj (All)")
ax.set_xlabel("Maj (arcsec)")
ax.set_ylabel("Count")

for ax in axs:
    ax.grid(alpha=0.3)
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.legend()

fig.show()

# %%
# Set peak fluxes
peak_map = map_cat["Peak_flux"].values[total_mask] * 1e3
peak_map_all = map_cat["Peak_flux"].values * 1e3
peak_model = cat["Peak_flux"].values[idx_model][total_mask] * 1e3
peak_model_all = cat["Peak_flux"].values * 1e3
peak_lofar = lofar_cat["Peak_flux"].values


# Flux and Size Histograms with LoTSS Data
fig, ax = plt.subplots(1, 1, figsize=(7, 5), constrained_layout=True)

bins = np.logspace(-2, 5, 100)
# plot_norm_hist(ax, f_map, bins=bins, label="Map Flux (Matched)")
plot_norm_hist(ax, peak_map_all, bins=bins, label="Map Peak Flux (All)")
plot_norm_hist(ax, peak_lofar, bins=bins, label="LoTSS Peak Flux")
plot_norm_hist(ax, peak_model, bins=bins, label="Model Peak Flux (Matched)")
# plot_norm_hist(ax, f_model_all, bins=bins, label="Model Flux (All)")

ax.set_xlabel("Peak Flux (mJy/beam)")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_ylim(bottom=1e-5)
ax.set_xlim(right=1e4)
ax.legend()

fig.show()

# %%
# Flux Offset scatter plot
# %matplotlib inline
fig, ax = plt.subplots(
    1,
    1,
    figsize=(8, 6),
    constrained_layout=True,)

scatter_kw = dict(s=0.1, alpha=0.8, marker='.')
ax.scatter(
    f_model,
    f_map - f_model,
    label=f"Map-Model",
    **scatter_kw,
)
# Plot 1:1 line
# ax.axline([0, 0], [1e-3, 1e-3], color="black", linestyle="--", alpha=0.25)
# ax.axhline(1, color="black", linestyle="--", alpha=0.25)

x = np.geomspace(0.1, 50, 100)
ax.plot(x, -x, color="black", linestyle="--", alpha=0.25)
ax.plot(x, 0.4-x, color="black", linestyle="--", alpha=0.25)

# Fit offset line
from scipy.optimize import curve_fit

def fit_func(x, a):
    return a + 0*x

popt, pcov = curve_fit(fit_func, f_model, f_map - f_model)
print(popt)
ax.plot(x, fit_func(x, *popt), color='orange', linestyle='--', alpha=0.8)


ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(left=0.3, right=30)
ax.set_ylim(bottom=-2, top=2)

#ax.set_xlabel("Model Flux (mJy)")
#ax.set_ylabel("Map Flux (mJy)")
ax.legend()
ax.grid(alpha=0.3)

fig.show()

# %%
# 2D Histogram of Flux Offset
import plotting.map_stat_plots as msp

reload(msp)

fig, ax, (xbins, ybins) = msp.hist2D_plot(
    f_model,
    f_map - f_model,
    nbins=50,
    xlim=(0.5, 30),
    ylim=(-1, 2),
    ax_labels=("Sky Model Flux (mJy)", "Flux Offset (mJy)"),
    log=(True, False),
    normalize="y",
)

# %%
# 2D Statistic: Model Size - Model Flux - Flux Offset
import plotting.map_stat_plots as msp

reload(msp)

fig, ax, (xbins, ybins) = msp.stat2d_plot(
    maj_model,
    f_model,
    f_map - f_model,
    nbins=25,
    xlim=(6, 20),
    ylim=(0.3, 10),
    zlim=1,
    ax_labels=("Sky Model Size (arcsec)", "Sky Model Flux (mJy)", "Flux Offset (mJy)"),
    log=(True, True, False),
    hist2d_kw=dict(log_color=True),
)

# %%
# Scatter-Histogram Plot for Sizes
import plotting.map_stat_plots as msp

reload(msp)

fig, axs, _ = msp.scat_hist_plot(
    maj_model,
    maj_map,
    ax_labels=("Sky Model Size (arcsec)", "Sim. Map Size (arcsec)"),
    plt_label="Model-Map",
    xlim=(5, 20),
    ylim=(5, 20),
    scatter_kw=dict(c=np.clip(f_model, a_max=10, a_min=1), s=0.2),
)

# %%
# 2D Statistic: Model Size - Map Size - Model Flux
import plotting.map_stat_plots as msp

reload(msp)

fig, axs, (xbins, ybins) = msp.stat2d_plot(
    maj_model,
    maj_map,
    f_model,
    nbins=50,
    xlim=(5, 20),
    ylim=(5, 20),
    # zlim=(1, 10),
    ax_labels=(
        "Sky Model Size (arcsec)",
        "Sim. Map Size (arcsec)",
        "Sky Model Flux (mJy)",
    ),
    log=(False, False, True),
    hist2d_kw=dict(log_color=True),
)

axs[0].plot(xbins, ybins, color="orange", linestyle="--", alpha=0.8)

# %%
# 2D Statistic: Model Size - Model Flux - Size Offset
import plotting.map_stat_plots as msp

reload(msp)

fig, axs, (xbins, ybins) = msp.stat2d_plot(
    maj_model,
    f_model,
    maj_map - maj_model,
    nbins=25,
    xlim=(6, 40),
    ylim=(0.3, 100),
    zlim=10,
    ax_labels=(
        "Sky Model Size (arcsec)",
        "Sky Model Flux (mJy)",
        "Size Offset (arcsec)",
    ),
    log=(True, True, False),
    hist2d_kw=dict(log_color=True),
)

# %%
# Scatter plot flux offset vs size offset
# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

size_offset = maj_cat - maj_model
flux_offset = f_map - f_model

scatter_kw = dict(s=0.1, alpha=0.8, marker='.')
ax.scatter(
    size_offset,
    flux_offset,
    label=f"Map-Model",
    **scatter_kw,
)

ax.set_xlim(left=-2.5, right=15)
ax.set_ylim(bottom=-1, top=2)
ax.grid(alpha=0.3)

ax.set_xlabel('Size Offset (arcsec)')
ax.set_ylabel('Flux Offset (mJy)')

fig.show()

# %%
# 2D Histogram for Flux Offset vs Size Offset
import plotting.map_stat_plots as msp

reload(msp)

fig, ax, (xbins, ybins) = msp.hist2D_plot(
    maj_map - maj_model,
    f_map - f_model,
    nbins=75,
    xlim=(-5, 15),
    ylim=(-1, 3),
    ax_labels=("Size Offset (arcsec)", "Flux Offset (mJy)"),
    log=(False, False),
    normalize="y",
    id_line=False,
)

# %%
# 2D Histogram for Sizes
import plotting.map_stat_plots as msp

reload(msp)

fig, ax, (xbins, ybins) = msp.hist2D_plot(
    maj_model,
    maj_map,
    nbins=50,
    xlim=(6, 25),
    ylim=(6, 25),
    ax_labels=("Sky Model Size (arcsec)", "Sim. Map Size (arcsec)"),
    normalize="y",
)

# %%
# Load pyBDSF model:
from maps.map_utils import beam_solid_angle

# Load PyBDSF Model Array
from maps.map_utils import get_image

ddf_residual_file = (
    paths.SKY_MAP_PARENT / map_name / ddf_parent / f"{map_name}.int.residual.fits"
)
ddf_residual_arr = get_image(ddf_residual_file, get_wcs=False).squeeze()

pyBDSF_model_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / f"{map_name}.bdsfNoise_pybdsf/model/{map_name}.bdsfNoise.pybdsf.model.fits"
)
bdsf_model_arr = get_image(pyBDSF_model_file, get_wcs=False).squeeze()

pyBDSF_map_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / ddf_parent
    / f"{map_name}.int.restored_pybdsf/model/{map_name}.int.restored.pybdsf.model.fits"
)
bdsf_map_arr = get_image(pyBDSF_map_file, get_wcs=False).squeeze()

map_arr, wcs_map = get_image(map_file, get_wcs=True)
map_arr = map_arr.squeeze()

# %%
# Plot Examples
# Function for plotting examples. For every example plot the following:
# Model cutout, map cutout pyBDSF model-model and pyBDSF map-model.
# Model and map cutout shoulkd have all TRECS sources in the cutout indicated.
import maps.map_utils as mputil
reload(mputil)

# flux_mask = (f_map > 1) & (f_map < 10)
# offset_mask = (f_map - f_model) <= 0.1
# selected_mask = flux_mask * offset_mask
flux_mask = f_model_all < 3e-2
selected_mask = flux_mask

cutout_size = 80
n_examples = 10

map_sub_cat = map_cat[total_mask][selected_mask]
idxs = np.random.choice(map_sub_cat.index, n_examples)

# %matplotlib inline
fig, axs = plt.subplots(n_examples, 5, figsize=(15, 3 * n_examples + 0.5), constrained_layout=True)

for i_ax, i in enumerate(idxs):
    # Get source coordinates from catalog entry
    source = map_sub_cat.loc[i]
    ra, dec = source["RA"], source["DEC"]

    # Get cutout of model
    ixmod, iymod = wcs.world_to_array_index_values(ra, dec)
    model_slices = (
        slice(int(ixmod - cutout_size / 2), int(ixmod + cutout_size / 2)),
        slice(int(iymod - cutout_size / 2), int(iymod + cutout_size / 2)),
    )
    model_cutout = mm.map_array[*model_slices]
    bdsf_model_cutout = bdsf_model_arr[*model_slices]

    # Get cutout of map and residual
    ixmap, iymap = wcs_map.world_to_array_index_values(ra, dec)
    map_slices = (
        slice(int(ixmap - cutout_size / 2), int(ixmap + cutout_size / 2)),
        slice(int(iymap - cutout_size / 2), int(iymap + cutout_size / 2)),
    )
    map_cutout = map_arr[*map_slices]
    bdsf_map_cutout = bdsf_map_arr[*map_slices]
    residual_cutout = ddf_residual_arr[*map_slices]


    # Find all TRECS sources in cutout
    neighbor_mask = crd_trecs.separation(SkyCoord(ra, dec, unit="deg")).arcsec < cutout_size / 2 * 1.5
    neighbors = crd_trecs[neighbor_mask]

    # Get cutout indices of neighbors
    ixmod_n, iymod_n = wcs.world_to_array_index_values(neighbors.ra, neighbors.dec)
    ixmod_n = ixmod_n - model_slices[0].start
    iymod_n = iymod_n - model_slices[1].start


    # vmax should be oriented on center of cutout
    vmax_range = 5  # pixel
    vmax = [
        cutout[ int(cutout_size / 2 - vmax_range):int(cutout_size / 2 + vmax_range) ].max() for cutout in [model_cutout, bdsf_model_cutout, map_cutout, residual_cutout, bdsf_map_cutout]
    ]

    axrow = axs[i_ax]

    # Plot cutouts
    axrow[0].imshow(model_cutout, vmax=vmax[0])
    axrow[1].imshow(bdsf_model_cutout, vmax=vmax[1])
    axrow[2].imshow(map_cutout, vmax=vmax[2])
    axrow[3].imshow(residual_cutout, vmax=vmax[3])
    axrow[4].imshow(bdsf_map_cutout, vmax=vmax[4])

    # Titles in first row
    if i_ax == 0:
        axrow[0].set_title("Model")
        axrow[1].set_title("PyBDSF Model")
        axrow[2].set_title("Map")
        axrow[3].set_title("Residual")
        axrow[4].set_title("PyBDSF Map")

    # Scatter TRECS sources
    for ax in axrow[0:2]:
        ax.scatter(iymod_n, ixmod_n, s=2, color='red', alpha=0.5)

    for ax in axrow.flatten():
        ax.axis('off')
    
    fig.show()

# %%
# Plot Examples
# Function for plotting examples. For every example plot the following:
# Model cutout, map cutout pyBDSF model-model and pyBDSF map-model.
# Model and map cutout shoulkd have all TRECS sources in the cutout indicated.
import maps.map_utils as mputil
reload(mputil)

# flux_mask = (f_map > 1) & (f_map < 10)
# offset_mask = (f_map - f_model) <= 0.1
# selected_mask = flux_mask * offset_mask
flux_mask = f_model_all < 1e-2
selected_mask = flux_mask

cutout_size = 80
n_examples = 10

model_sub_cat = cat[selected_mask]
idxs = np.random.choice(model_sub_cat.index, n_examples)

# %matplotlib inline
fig, axs = plt.subplots(n_examples, 5, figsize=(15, 3 * n_examples + 0.5), constrained_layout=True)

for i_ax, i in enumerate(idxs):
    # Get source coordinates from catalog entry
    source = model_sub_cat.loc[i]
    ra, dec = source["RA"], source["DEC"]

    # Get cutout of model
    ixmod, iymod = wcs.world_to_array_index_values(ra, dec)
    model_slices = (
        slice(int(ixmod - cutout_size / 2), int(ixmod + cutout_size / 2)),
        slice(int(iymod - cutout_size / 2), int(iymod + cutout_size / 2)),
    )
    model_cutout = mm.map_array[*model_slices]
    bdsf_model_cutout = bdsf_model_arr[*model_slices]

    # Get cutout of map and residual
    ixmap, iymap = wcs_map.world_to_array_index_values(ra, dec)
    map_slices = (
        slice(int(ixmap - cutout_size / 2), int(ixmap + cutout_size / 2)),
        slice(int(iymap - cutout_size / 2), int(iymap + cutout_size / 2)),
    )
    map_cutout = map_arr[*map_slices]
    bdsf_map_cutout = bdsf_map_arr[*map_slices]
    residual_cutout = ddf_residual_arr[*map_slices]


    # Find all TRECS sources in cutout
    neighbor_mask = crd_trecs.separation(SkyCoord(ra, dec, unit="deg")).arcsec < cutout_size / 2 * 1.5
    neighbors = crd_trecs[neighbor_mask]

    # Get cutout indices of neighbors
    ixmod_n, iymod_n = wcs.world_to_array_index_values(neighbors.ra, neighbors.dec)
    ixmod_n = ixmod_n - model_slices[0].start
    iymod_n = iymod_n - model_slices[1].start


    # vmax should be oriented on center of cutout
    vmax_range = 8  # pixel
    vmax_slice = slice(int(cutout_size / 2 - vmax_range), int(cutout_size / 2 + vmax_range))
    vmax = [
        cutout[vmax_slice, vmax_slice].max() for cutout in [model_cutout, bdsf_model_cutout, map_cutout, residual_cutout, bdsf_map_cutout]
    ]

    axrow = axs[i_ax]

    # Plot cutouts
    axrow[0].imshow(model_cutout + np.random.normal(0, scale=5e-8, size=model_cutout.shape), vmax=vmax[0])
    axrow[1].imshow(bdsf_model_cutout, vmax=vmax[1])
    axrow[2].imshow(map_cutout, vmax=vmax[2])
    axrow[3].imshow(residual_cutout, vmax=vmax[3])
    axrow[4].imshow(bdsf_map_cutout, vmax=vmax[4])

    # Titles in first row
    if i_ax == 0:
        axrow[0].set_title("Model")
        axrow[1].set_title("PyBDSF Model")
        axrow[2].set_title("Map")
        axrow[3].set_title("Residual")
        axrow[4].set_title("PyBDSF Map")

    # Scatter TRECS sources
    for ax in axrow[0:2]:
        ax.scatter(iymod_n, ixmod_n, s=2, color='red', alpha=0.5)

    for ax in axrow.flatten():
        ax.axis('off')
    
    fig.show()

# %% [markdown]
# ### Model vs TRECS

# %%
import astropy.units as u

# Match model cat and trecs cat
idx_model_trecs, d2d_model_trecs, d3d_model_trecs = crd_model.match_to_catalog_sky(
    crd_trecs
)

# Out of the matched sources, select the ones where the TRECS source is isolated.
isol_dist = 30  # arcsec
trecs_match = crd_trecs[idx_model_trecs]
idx0, _, _, _ = trecs_match.search_around_sky(trecs_match, isol_dist * u.arcsec)
idxu, counts = np.unique(idx0, return_counts=True)
isol_mask = counts == 1

print(
    f"Matched {isol_mask.sum()} isolated sources out of {len(isol_mask)}: {isol_mask.sum() / len(isol_mask):.2%}"
)

idx_model_trecs_isol = idx_model_trecs[isol_mask]
d2d_model_trecs_isol = d2d_model_trecs[isol_mask]
d3d_model_trecs_isol = d3d_model_trecs[isol_mask]

# %%
# DIstribution of distances

fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

ax.hist(
    d2d_model_trecs.arcsec,
    bins=np.linspace(0, 25, 100),
    cumulative=False,
    log=False,
    label="All",
    histtype="step",
)
ax.hist(
    d2d_model_trecs_isol.arcsec,
    bins=np.linspace(0, 25, 100),
    cumulative=False,
    log=False,
    label="Isolated",
    histtype="step",
)
ax.set_xlabel("Distance [arcsec]")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)
ax.set_yscale("log")
ax.legend()

fig.suptitle("Model Catalog vs. TRECS Catalog")
fig.show()

# %%
# Get peak_flux values from mm
comp_peak = {i: img.max() for i, img in zip(mm.comp_df["TRECS_index"], mm.comp_images)}
ext_peak = {
    i: img.max() for i, img in zip(mm.ext_df["TRECS_index"], mm.ext_data["images"])
}
mm_peak = np.ones(len(trecs_cat)) * -1

np.put(mm_peak, list(comp_peak.keys()), list(comp_peak.values()))
np.put(mm_peak, list(ext_peak.keys()), list(ext_peak.values()))

# %%
from maps.map_utils import beam_solid_angle



# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 5

trecs_flux = trecs_cat["I144"].values[idx_model_trecs][dist_mask]
model_flux = cat["Total_flux"].values[dist_mask] * 1e3

# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(8, 6), constrained_layout=True, dpi=100)


# Plotting parameters
plt_kwargs = dict(s=1, alpha=0.5)

ax.scatter(
    trecs_flux,
    model_flux,
    label="Total Flux",
    **plt_kwargs,
)
ax.set_xlabel("TRECS Flux (mJy)")
ax.set_ylabel("Sky Model Flux (mJy)")


# Plot 1:1 line
ax.axline([0, 0], [1, 1], color="red", linestyle="--", alpha=0.25)

# Plot min. line of double blended source
size_offset = trecs_flux.min()
x = np.logspace(-2, 2, 500)
ax.plot(x, x + size_offset, color="orange", linestyle="--", alpha=0.8)
# ax.plot(x, x + 2*offset, color="orange", linestyle="--", alpha=0.4)
#ax.axline([0, offset], [1, 1+offset], color="orange", linestyle="--", alpha=0.25)

ax.legend()
ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlim(7e-2, 1e1)
ax.set_ylim(7e-2, 1e1)
ax.grid(alpha=0.3)



fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Make a custom cmap with 6 sequential colors
from matplotlib.colors import LinearSegmentedColormap

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]
cmap = LinearSegmentedColormap.from_list("custom", colors, N=len(colors))

# %%
from maps.map_utils import beam_solid_angle
from matplotlib import cm

# Scatter plot in vs. out for different quantities: Total_flux, Peak_flux and 2xDC_Maj
# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(8, 9), constrained_layout=True, dpi=100)

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 5
total_mask = dist_mask * isol_mask
f_trecs = trecs_cat["I144"].values[idx_model_trecs][total_mask]
f_map = cat["Total_flux"].values[total_mask] * 1e3
ratio = f_trecs / f_map
size_offset = f_map - f_trecs
cl = trecs_cat['RadioClass'].values[idx_model_trecs][total_mask]

# Plotting parameters
plt_kwargs = dict(s=1, alpha=0.6)

sc = ax.scatter(
    f_trecs, size_offset,
    label="Flux Offset",
    c=cl,
    cmap=cmap,
    **plt_kwargs,
)
fig.colorbar(sc)
# ax.set_xlim(0, 5)
ax.set_ylim(-0.25, 0.25)
ax.set_xlabel("TRECS Flux (mJy)")
ax.set_ylabel("Offset (mJy)")

# Plot horizontal line at apparent cut between components

ax.legend()
ax.set_xscale("log")
# ax.set_yscale("log")
ax.grid(alpha=0.3)



fig.show()

# %%
f_trecs.min()

# %%
dist_mask = d2d_model_trecs.arcsec < 5
total_mask = dist_mask

f_trecs = trecs_cat["I144"].values[idx_model_trecs][dist_mask]
f_model = cat["Total_flux"].values[dist_mask] * 1e3

# %matplotlib inline
fig, axs = plt.subplots(
    2,
    2,
    figsize=(7, 7),
    constrained_layout=True,
    width_ratios=[1, 0.5],
    height_ratios=[0.5, 1],
    sharex='col',
    sharey='row',
)

ax = axs[0][0]
ax.hist(f_trecs, bins=np.logspace(*auto_log_range((f_trecs,)), num=100), log=True, label="TRECS")

ax = axs[0][1]
# remove axis
ax.axis("off")

ax = axs[1][1]
ax.hist(f_model, bins=np.logspace(*auto_log_range((f_model,)), num=100), log=False, orientation="horizontal", label="Model")
ax.set_xscale('log') 
ax.set_xlim(left=1e-1, right=1e5)


ax = axs[1][0]
ax.scatter(
    f_trecs,
    f_model,
    s=0.01,
    alpha=0.8,
    label=f"Total Flux",
)
# Plot 1:1 line
ax.axline([0, 0], [1e-3, 1e-3], color="black", linestyle="--", alpha=0.25)

# plot horizontal line at trecs cut-off
ax.axhline(f_trecs.min(), color='red', linestyle='--', alpha=0.5, label='TRECS Min.')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(right=1e1)
ax.set_ylim(bottom=5e-2, top=1e1)

ax.set_xlabel("TRECS Flux (mJy)")
ax.set_ylabel("Model Flux (mJy)")
for ax in axs.flatten():
    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
# Plot model with all sources scattered that are not matched and that are below
# Trecs flux cut
import matplotlib.pyplot as plt
import plotting.map_plots as mpplt
from astropy.coordinates import SkyCoord
import maps.map_utils as mputil
reload(mputil)
reload(mpplt)


data_arr, data_wcs = get_image(model_file)

# Plot map
# %matplotlib widget
fig, ax, _ = mpplt.plot_sky_map(data_arr, wcs=data_wcs)

# Plot PyBDSF sources
dist_mask_inv = d2d_model_trecs.arcsec > 5
flux_mask = cat['Total_flux'] * 1e3 < f_trecs.min()
print(flux_mask.sum())

flux_mask = f_trecs < 1
offset_mask = offset > 0.08
scatter_mask = flux_mask * offset_mask
ax.scatter_coord(crd_model[dist_mask][scatter_mask], s=0.1, color='red')
ax.scatter_coord(crd_trecs, s=0.1, color='blue')

fig.show()

# %%
from maps.map_utils import beam_solid_angle

# Load PyBDSF Model Array
from maps.map_utils import get_image

pyBDSF_model_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / f"{map_name}.bdsfNoise_pybdsf/model/{map_name}.bdsfNoise.pybdsf.model.fits"
)
bdsf_model_arr = get_image(pyBDSF_model_file, get_wcs=False).squeeze()

# %%
reload(mpplt)

mpplt.double_map_plot(
    mm.map_array,
    bdsf_model_arr.squeeze() * 1.5**2 / beam_solid_angle(6),
    size=(18, 9),
)

# %%
from tqdm import tqdm

# Plot examples
sub_cat = trecs_cat.iloc[idx_model_trecs[scatter_mask]]

cutout_blueprint = np.zeros((40, 40))

x, y = sub_cat["x_coord"], sub_cat["y_coord"]
cutouts = [
    mm.map_array[
        mputil.get_source_slice(
            (x.values[i], y.values[i]),
            cutout_blueprint,
            mm.map_array,
            mm.map_size_deg,
            truncate_edge=False,
        )[0]
    ]
    for i in tqdm(range(len(sub_cat)), desc=f"Model cutouts")
]

bdsf_cutouts = [
    bdsf_model_arr[
        mputil.get_source_slice(
            (x.values[i], y.values[i]),
            cutout_blueprint,
            bdsf_model_arr,
            mm.map_size_deg,
            truncate_edge=False,
        )[0]
    ].squeeze()
    for i in tqdm(range(len(sub_cat)), desc=f"BDSF cutouts")
]

# %%
# Random examples
# %matplotlib inline
idxs = np.random.choice(len(sub_cat), 4, replace=False)

for i in idxs:
    fig, axs = plt.subplots(1, 2, figsize=(8, 4), constrained_layout=True)

    axs[0].imshow(cutouts[i])
    axs[0].set_title("Sky Model")
    axs[1].imshow(bdsf_cutouts[i])
    axs[1].set_title("PyBDSF Model")

    fig.suptitle(f"Source No. {i}")

    for ax in axs:
        ax.axis("off")

    fig.show()

# %%
# Scatter plot in vs. out for different quantities: Total_flux, Peak_flux and 2xDC_Maj
fig, ax = plt.subplots(1, 1, figsize=(8, 4), constrained_layout=True, dpi=150)

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.25

# Plotting parameters
plt_kwargs = dict(s=2, alpha=0.7)

trecs_size = trecs_cat["size"].values
sfg_flag = trecs_cat["RadioClass"].values <= 3
trecs_size[sfg_flag] = trecs_cat["bmaj"].values[sfg_flag]
total_mask = dist_mask * isol_mask

fig.colorbar(
    ax.scatter(
        trecs_cat["I144"].values[idx_model_trecs][total_mask] * 1e-3,
        cat["Total_flux"].values[total_mask],
        c=np.clip(trecs_size[idx_model_trecs][total_mask], a_min=None, a_max=1),
        **plt_kwargs,
    )
)

# Plot 1:1 line
ax.axline([0, 0], [1, 1], color="black", linestyle="--", alpha=0.25)
ax.set_xlabel("TRECS")
ax.set_ylabel("Sky Model")
ax.legend()
ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)

ax.set_xlim(6e-5, 1e-2)
ax.set_ylim(3e-5, 1e-2)

fig.suptitle("Total Flux (Jy)")

fig.show()

# %%
# Plot flux distributions of matched sources
fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

dist_mask = d2d_model_trecs.arcsec < 3
total_mask = dist_mask * isol_mask

ax.hist(
    trecs_cat["I144"].values[idx_model_trecs][total_mask] * 1e-3,
    bins=np.logspace(-5, -2, 100),
    cumulative=False,
    log=True,
    label="TRECS",
    histtype="step",
)

ax.hist(
    cat["Total_flux"].values[total_mask],
    bins=np.logspace(-5, -2, 100),
    cumulative=False,
    log=True,
    label="Sky Model",
    histtype="step",
)

ax.set_xlabel("Total Flux [Jy]")
ax.set_ylabel("Count")

ax.set_xscale("log")

ax.grid(alpha=0.3)
ax.legend()

fig.show()

# %%
# Scatter plot sizes for different populations of TRECS sources
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, axs = plt.subplots(2, 3, figsize=(10, 7), constrained_layout=True)

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.2
single_mask = cat["S_Code"].values.astype(str) == "S"

for ax, (key, label) in zip(axs.flatten(), class_dict.items()):

    cls_mask = trecs_cat["RadioClass"].values[idx_model_trecs] == key
    total_mask = dist_mask * cls_mask * single_mask
    ax.scatter(
        trecs_cat["bmaj" if key <= 3 else "size"].values[idx_model_trecs][total_mask],
        cat["DC_Maj"].values[total_mask] * 3600,
        label=label,
        **plt_kwargs,
    )

    # Plot 1:1 line
    ax.axline([0, 0], [1e-5, 1e-5], color="black", linestyle="--", alpha=0.25)
    ax.legend()
    # ax.set_xscale("log")
    # ax.set_yscale("log")
    ax.grid(alpha=0.3)

# set_xmax(ax, 0.2)
# set_ymax(ax, 0.2)
fig.supxlabel("TRECS Size (arcsec)")
fig.supylabel("Sky Model 2xDC_Maj (arcsec)")

fig.show()

# %%
# Plot size distribution for all classes
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, axs = plt.subplots(2, 2, figsize=(14, 8), sharex="col", tight_layout=True)

fig.suptitle("Matched Sources", fontsize="xx-large")

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 2
single_mask = cat["S_Code"].values.astype(str) == "S"

# Plot TRECS data
for key, pop_name in class_dict.items():
    cls_mask = trecs_cat["RadioClass"].values[idx_model_trecs] == key

    # SFGs:
    if key <= 3:

        bins = np.logspace(-1, 2.1, 100)

        # TRECS Distirbution
        ax = axs[0][0]
        ax.set_title("TRECS SFGs:")
        size = trecs_cat["bmaj"].values[idx_model_trecs][dist_mask * cls_mask]
        ax.hist(size, bins=bins, histtype="step", label=pop_name, density=False)

        # Sky Model Distribution
        ax = axs[1][0]
        ax.set_title("Sky Model SFGs:")
        size = cat["DC_Maj"].values[dist_mask * cls_mask] * 3600
        ax.hist(size, bins=bins, histtype="step", label=pop_name, density=False)

    # AGNs:
    else:
        bins = np.logspace(-5, 3, 100)

        # TRECS Distirbution
        ax = axs[0][1]
        ax.set_title("TRECS AGNs:")
        size = trecs_cat["size"].values[idx_model_trecs][dist_mask * cls_mask]
        ax.hist(size, bins=bins, histtype="step", label=pop_name, density=False)

        # Sky Model Distribution
        ax = axs[1][1]
        ax.set_title("Sky Model AGNs:")
        size = cat["DC_Maj"].values[dist_mask * cls_mask] * 3600
        ax.hist(size, bins=bins, histtype="step", label=pop_name, density=False)

    # Activate x tick labels
    ax.tick_params(axis="x", labelbottom=True)

fig.supxlabel("Size [arcsec]")

for ax in axs.flatten():
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.legend()
    ax.grid(alpha=0.3)
    ax.axvline(6, color="black", linestyle="--", alpha=0.25)

    ax.set_ylabel("Counts")

fig.show()

# %%
# Plot size distributions of model for extended and compact sources
fig, ax = plt.subplots(1, 1, figsize=(10, 7), constrained_layout=True)

dist_mask = d2d_model_trecs.arcsec < 2
comp_flag = (trecs_cat["RadioClass"].values[idx_model_trecs] < 6) | (
    trecs_cat["size"].values[idx_model_trecs] <= 1.5
)

bins = np.logspace(0, 2.5, 100)

# Compact sources
size = 2 * cat["DC_Maj"].values[dist_mask * comp_flag] * 3600
ax.hist(size, bins=bins, histtype="step", label="Compact", density=False)

# Extended sources
size = 2 * cat["DC_Maj"].values[dist_mask * ~comp_flag] * 3600
ax.hist(size, bins=bins, histtype="step", label="Extended", density=False)

ax.set_xscale("log")
ax.set_yscale("log")
ax.legend()
ax.grid(alpha=0.3)

ax.set_xlabel("Size [arcsec]")
ax.set_ylabel("Counts")

fig.show()

# %%
# Plot size ratios for different populations
# Plot size distribution for all classes
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, ax = plt.subplots(1, 1, figsize=(8, 5), sharex=False, tight_layout=True)

fig.suptitle("Matched Sources", fontsize="xx-large")

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.2
single_mask = cat["S_Code"].values.astype(str) == "S"

# Plot TRECS data
for key, pop_name in class_dict.items():
    cls_mask = trecs_cat["RadioClass"].values[idx_model_trecs] == key

    # SFGs:
    if key <= 5:

        bins = np.linspace(0, 40, 100)
        total_mask = dist_mask * cls_mask * single_mask

        # TRECS Distirbution
        ax.set_title("Compact:")
        ratio = (
            2
            * cat["DC_Maj"].values[total_mask]
            * 3600
            / trecs_cat["bmaj" if key <= 3 else "size"].values[idx_model_trecs][
                total_mask
            ]
        )
        ax.hist(
            ratio[np.isfinite(ratio)],
            bins=bins,
            histtype="step",
            label=pop_name,
            density=False,
        )

    # AGNs:
    else:
        continue

    # Activate x tick labels
    ax.tick_params(axis="x", labelbottom=True)

ax.set_xlabel("Size Ratio (Sky Model / TRECS)")
ax.set_yscale("log")
ax.legend()
ax.grid(alpha=0.3)

ax.set_ylabel("Counts")

fig.show()

# %%
# Plot example cutouts for different populations.
# Steps:
# - Make a dictionary with the different populations, where the values are
#   tuples with the indices of the sources in the TRECS catalog, and the
#   corresponding size ratios.
#
# - For each population, get the cutouts of the sources in the model from the
#   MapMaker object.
#
# - Use metric_peek to plot examples.

import plotting.image_plots as iplt

reload(iplt)
from plotting.image_plots import metric_peek
from tqdm import tqdm

# Make dictionary with populations
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.2
single_mask = cat["S_Code"].values.astype(str) == "S"


size_ratio_dict = {
    key: (
        dist_mask := (
            (trecs_cat["RadioClass"].values[idx_model_trecs] == key)
            * dist_mask
            * single_mask
        ),
        cat["DC_Maj"].values[dist_mask]
        * 3600
        / trecs_cat["bmaj" if key <= 3 else "size"].values[idx_model_trecs][dist_mask],
    )
    for key in class_dict.keys()
}

# Bin edges
bins = {
    "late-type": np.linspace(0, 20, 5),
    "spheroidal": np.linspace(0, 80, 5),
    "lensed spheroidal": np.linspace(0, 40, 5),
}


for key, (idxs, ratios) in size_ratio_dict.items():
    print(f"{class_dict[key]}: {idxs.shape[0]:_} sources")

    sub_cat = trecs_cat.iloc[idx_model_trecs][idxs]
    x, y = sub_cat["x_coord"], sub_cat["y_coord"]
    cutouts = [
        mm.map_array[
            mputil.get_source_slice(
                (x.values[i], y.values[i]),
                np.zeros((20, 20)),
                mm.map_array,
                mm.map_size_deg,
                truncate_edge=False,
            )[0]
        ]
        for i in tqdm(range(len(sub_cat)), desc=f"{class_dict[key]} cutouts")
    ]
    sizes = sub_cat["bmaj"].values
    titles = [f"Size={s:.2f} arcsec" for s in sizes]

    metric_peek(
        ratios,
        bins[class_dict[key]],
        cutouts,
        metric_name="Ratio",
        names=titles,
        n_examples=10,
    )

    break

# %%
# Plot the size ratios against the sizes of the sources for all SFGs
# Plot size ratios for different populations
# Plot size distribution for all classes
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, ax = plt.subplots(1, 1, figsize=(8, 6), sharex=False, tight_layout=True)

fig.suptitle("Matched Sources", fontsize="xx-large")

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.2
single_mask = cat["S_Code"].values.astype(str) == "S"

# Plot TRECS data
for key, pop_name in class_dict.items():
    cls_mask = trecs_cat["RadioClass"].values[idx_model_trecs] == key
    total_mask = dist_mask * cls_mask * single_mask

    # Compacts:
    if key <= 5:

        bins = np.linspace(0, 150, 100)

        # TRECS Distirbution
        ax.set_title("Compact Sources:")
        size_TRECS = trecs_cat["bmaj"].values[idx_model_trecs][total_mask]
        size_model = cat["DC_Maj"].values[total_mask] * 3600 * 2
        model_flux = cat["Total_flux"].values[total_mask]
        sc = ax.scatter(
            size_TRECS,
            size_model,
            label=pop_name,
            s=3,
            alpha=0.5,
        )

    # AGNs:
    else:
        continue

    # Activate x tick labels
    ax.tick_params(axis="x", labelbottom=True)


ax.axvline(6, color="black", linestyle="--", alpha=0.25, label="6 arcsec")
ax.axline([0, 0], [1, 1], color="red", linestyle="--", alpha=0.25, label="1:1")

ax.set_xlabel("TRECS Size")
ax.set_ylabel("Model Size")

# ax.set_xscale("log")
# ax.set_yscale("log")
ax.legend()
ax.grid(alpha=0.3)

set_xmax(ax, 15)
set_ymax(ax, 15)


fig.show()

# %%
# Plot the size ratios against the sizes of the sources for all SFGs
# Plot size ratios for different populations
# Plot size distribution for all classes
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, ax = plt.subplots(1, 1, figsize=(8, 6), sharex=False, tight_layout=True)

fig.suptitle("Matched Sources", fontsize="xx-large")

# Exclude matches with too large distance
dist_mask = d2d_model_trecs.arcsec < 1.2
single_mask = cat["S_Code"].values.astype(str) == "S"

cls_mask = trecs_cat["RadioClass"].values[idx_model_trecs] <= 5
total_mask = dist_mask * cls_mask * single_mask

# TRECS Distirbution
ax.set_title("SFGs:")
size_TRECS = np.array(
    [
        bmaj if key <= 3 else size
        for bmaj, size, key in zip(
            trecs_cat["bmaj"].values[idx_model_trecs][total_mask],
            trecs_cat["size"].values[idx_model_trecs][total_mask],
            trecs_cat["RadioClass"].values[idx_model_trecs][total_mask],
        )
    ]
)
flux_TRECS = trecs_cat["I144"].values[idx_model_trecs][total_mask] * 1e-3
size_model = cat["DC_Maj"].values[total_mask] * 3600 * 2
E_size_model = cat["E_DC_Maj"].values[total_mask] * 3600 * 2
model_flux = cat["Total_flux"].values[total_mask]
flux_SNR = model_flux / cat["E_Total_flux"].values[total_mask]
flux_ratio = model_flux / flux_TRECS
sc = ax.scatter(
    size_TRECS,
    size_model,
    # label=pop_name,
    s=3,
    alpha=0.5,
    c=np.clip(flux_ratio, a_min=1, a_max=None),
    cmap="cool",
)
fig.colorbar(sc)

# Activate x tick labels
ax.tick_params(axis="x", labelbottom=True)


ax.axvline(6, color="black", linestyle="--", alpha=0.25, label="6 arcsec")
ax.axline([0, 0], [1, 1], color="red", linestyle="--", alpha=0.25, label="1:1")

ax.set_xlabel("TRECS Size")
ax.set_ylabel("Model Size")

# ax.set_xscale("log")
# ax.set_yscale("log")
ax.legend()
ax.grid(alpha=0.3)

set_xmax(ax, 15)
set_ymax(ax, 15)


fig.show()

# %%
print(flux_ratio.min(), flux_ratio.max(), flux_ratio.mean(), np.median(flux_ratio))
plt.hist(flux_ratio, bins=np.linspace(0, 5, 100), log=True)

# %% [markdown]
# ### Map vs TRECS

# %%
# Run matching
idx_map_trecs, d2d_map_trecs, _ = crd_map.match_to_catalog_sky(crd_trecs)

# For duplicates choose the closest source
unique_mask = get_unique_mask(idx_map_trecs, d2d_map_trecs)

len(idx_map_trecs), unique_mask.sum()

# %%
# Scatter plot in vs. out for different quantities: Total_flux, Peak_flux and 2xDC_Maj

# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(8, 9), constrained_layout=True, dpi=100)

# Exclude matches with too large distance
dist_mask = d2d_map_trecs.arcsec < 5

# Plotting parameters
plt_kwargs = dict(s=1, alpha=0.5)

ax.scatter(
    trecs_cat["I144"].values[idx_map_trecs][dist_mask] * 1e-3,
    map_cat["Total_flux"].values[dist_mask],
    label="Total Flux",
    **plt_kwargs,
)
#ax.set_xlim(6e-5, 1e-2)
#ax.set_ylim(3e-5, 1e-2)


# Plot 1:1 line
ax.axline([0, 0], [1, 1], color="red", linestyle="--", alpha=0.25)
ax.set_xlabel("TRECS")
ax.set_ylabel("Sky map")
ax.legend()
ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)



fig.show()

# %%
from maps.map_utils import beam_solid_angle



# Exclude matches with too large distance
dist_mask = d2d_map_trecs.arcsec < 5

trecs_flux = trecs_cat["I144"].values[idx_map_trecs][dist_mask]
map_flux = map_cat["Total_flux"].values[dist_mask] * 1e3

# %matplotlib widget
fig, ax = plt.subplots(1, 1, figsize=(8, 6), constrained_layout=True, dpi=100)


# Plotting parameters
plt_kwargs = dict(s=1, alpha=0.5)

ax.scatter(
    trecs_flux,
    map_flux,
    label="Total Flux",
    **plt_kwargs,
)
ax.set_xlabel("TRECS Flux (mJy)")
ax.set_ylabel("Sky map Flux (mJy)")


# Plot 1:1 line
ax.axline([0, 0], [1, 1], color="red", linestyle="--", alpha=0.25)

# Plot min. line of double blended source
size_offset = trecs_flux.min()
x = np.logspace(-2, 2, 500)
ax.plot(x, x + size_offset, color="orange", linestyle="--", alpha=0.8)
ax.plot(x, x + 2*size_offset, color="orange", linestyle="--", alpha=0.4)
#ax.axline([0, offset], [1, 1+offset], color="orange", linestyle="--", alpha=0.25)

ax.legend()
ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlim(3e-1, 1e1)
ax.set_ylim(3e-1, 1e1)
ax.grid(alpha=0.3)



fig.show()

# %%
dist_mask = d2d_map_trecs.arcsec < 5
total_mask = dist_mask * unique_mask

f_trecs = trecs_cat["I144"].values[idx_map_trecs][total_mask]
f_trecs_all = trecs_cat["I144"].values
f_map = map_cat["Total_flux"].values[total_mask] * 1e3
f_map_all = map_cat["Total_flux"].values * 1e3

dist_mask_model = d2d_model_trecs.arcsec < 5
unique_mask_model = get_unique_mask(idx_model_trecs, d2d_model_trecs)
total_mask_model = dist_mask_model * unique_mask_model
f_trecs_model = trecs_cat["I144"].values[idx_model_trecs][total_mask_model]
f_model = cat["Total_flux"].values[total_mask_model] * 1e3

# %matplotlib inline
fig, axs = plt.subplots(
    2,
    2,
    figsize=(9, 9),
    constrained_layout=True,
    width_ratios=[1, 0.66],
    height_ratios=[0.66, 1],
    sharex='col',
    sharey='row',
)

bins = np.logspace(*auto_log_range((f_trecs, f_trecs_model)), num=100)
hist_kw = dict(histtype="step", bins=bins)

ax = axs[0][0]
ax.hist(f_trecs_model, log=True, label="TRECS-Model", **hist_kw)
ax.hist(f_trecs, log=True, label="TRECS-Map", **hist_kw)


ax = axs[0][1]
# remove axis
ax.axis("off")


ax = axs[1][1]
hist_kw['orientation'] = 'horizontal'
hist_kw['bins'] = np.logspace(*auto_log_range((f_model, f_map, f_map_all, f_trecs_all)), num=100)
ax.hist(f_model, log=False, label="TRECS-Model", **hist_kw)
#ax.plot([], [])
ax.hist(f_map, log=False, label="TRECS-Map", **hist_kw)
ax.hist(f_map_all, log=False, label="Map (All)", **hist_kw)
# ax.hist(f_trecs_all, log=False, label="TRECS (All)", **hist_kw)
ax.set_xscale('log') 
ax.set_xlim(left=1e-1, right=1e5)


ax = axs[1][0]
scatter_kw = dict(s=0.01, alpha=0.8, marker='.')
ax.scatter(
    f_trecs_model,
    f_model,
    label=f"TRECS-Model",
    **scatter_kw,
)
ax.scatter(
    f_trecs,
    f_map,
    label=f"TRECS-Map",
    **scatter_kw,
)
# Plot 1:1 line
ax.axline([0, 0], [1e-3, 1e-3], color="black", linestyle="--", alpha=0.25)

# Plot min. line of double blended source
size_offset = trecs_flux.min()
x = np.logspace(-2, 2, 500)
ax.plot(x, x + size_offset, color="green", linestyle="--", alpha=0.3, label='y(x) = x + TRECS Min.')

# plot horizontal line at trecs cut-off
ax.axhline(f_trecs.min(), color='red', linestyle='--', alpha=0.3, label='TRECS Min.')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(right=1e2)
ax.set_ylim(bottom=5e-2, top=1e2)

ax.set_xlabel("TRECS Flux (mJy)")
ax.set_ylabel("map Flux (mJy)")
for ax in axs.flatten():
    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
# Plot flux distribution for matched map sources,
# Put flux distribution ffor unmatched ones on top of it, and also show
# TRECS distribution.

fig, ax = plt.subplots(1, 1, figsize=(7, 4), constrained_layout=True)

bins = np.logspace(*auto_log_range((f_map_all, f_trecs_all)), 100)
hist_kw = dict(
    histtype="step",
)  # bins=bins, log=True)

dist_mask = d2d_map_trecs.arcsec < 5
total_mask = dist_mask * unique_mask

ax.hist(
    f_map,
    bins=bins,  # np.logspace(*auto_log_range((f_map,)), num=100),
    log=False,
    label="TRECS-Map",
    **hist_kw
)
ax.hist(
    f_map_all,
    bins=np.logspace(*auto_log_range((f_map_all,)), num=100),
    log=False,
    label="Map (All)",
    **hist_kw
)
ax.hist(
    f_trecs_all,
    bins=np.logspace(*auto_log_range((f_trecs_all,)), num=100),
    log=False,
    label="TRECS (All)",
    **hist_kw
)

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)
ax.legend()
ax.set_xlim(right=1e2)
ax.set_ylim(bottom=1e-1, top=1e5)

fig.show()

# %%
# Plot map with scatter of all sources attributed to the bump between 
# 1 and 20 mJy

import matplotlib.pyplot as plt
import plotting.map_plots as mpplt
from astropy.coordinates import SkyCoord
import maps.map_utils as mputil
reload(mputil)
reload(mpplt)


data_arr, data_wcs = get_image(map_file)

# Plot map
# %matplotlib widget
fig, ax, _ = mpplt.plot_sky_map(data_arr, wcs=data_wcs)

# Plot PyBDSF sources
f_map_all = map_cat["Total_flux"].values * 1e3
flux_mask = (f_map_all > 1) & (f_map_all < 20)
scatter_mask = flux_mask * (~total_mask)
ax.scatter_coord(crd_map[scatter_mask], s=0.5, color='red')
ax.scatter_coord(crd_trecs, s=0.5, color='blue')

fig.show()

# %%
# Load PyBDSF Model Array
from maps.map_utils import get_image

pyBDSF_model_file = (
    paths.SKY_MAP_PARENT
    / map_name
    / f"ddf/{map_name}.int.restored_pybdsf/model/{map_name}.int.restored.pybdsf.model.fits"
)
bdsf_model_arr = get_image(pyBDSF_model_file, get_wcs=False).squeeze()

sky_map_array = get_image(map_file, get_wcs=False).squeeze()

# %%
reload(mpplt)

mpplt.double_map_plot(
    sky_map_array,
    bdsf_model_arr.squeeze(),
    size=(18, 9),
)

# %% [markdown]
# ## Source Counts

# %%
from analysis.stats_utils import err_poisson
# %matplotlib inline

S_map = map_cat["Total_flux"].values
S_model = cat["Total_flux"].values
S_model_matched = cat["Total_flux"][idx_model][total_mask].values
S_lofar = lofar_cat["Total_flux"].values * 1e-3
S_trecs = trecs_cat["I144"].values * 1e-3


fig, ax = plt.subplots(1, 1, figsize=(8, 5), constrained_layout=True, dpi=200)

plot_dict = {
    "Sky Map": S_map,
    "LoTSS-DR2": S_lofar,
    "Sky Model": S_model,
    # "TRECS": S_trecs,
}

for label, S in plot_dict.items():

    counts, bins = np.histogram(S, bins=np.logspace(-4.2, 1, 100), density=False)
    err_lo, err_hi = err_poisson(counts)

    def scale_counts(counts, bins, area_degsq=25):
        bin_centers = (bins[1:] + bins[:-1]) / 2
        bin_width = bins[1:] - bins[:-1]
        norm_counts = counts / bin_width * bin_centers ** (5 / 2)  # Jy**1.5
        norm_counts *= 1 / (area_degsq * (np.pi / 180) ** 2)  # Jy**1.5 / sr
        return norm_counts

    scale_kw = dict(bins=bins, area_degsq=(5634 if label == "LoTSS-DR2" else 25))

    counts_sc = scale_counts(counts, **scale_kw)
    err_lo_sc = scale_counts(err_lo, **scale_kw)
    err_hi_sc = scale_counts(err_hi, **scale_kw)

    p = ax.stairs(
        counts_sc,
        bins,
        label=label,
        ls="--" if label == "Sky Model" else "-",
    )
    ax.errorbar(
        (bins[1:] + bins[:-1]) / 2,
        counts_sc,
        yerr=(err_lo_sc, err_hi_sc),
        ls="none",
        color=p.get_edgecolor(),
        alpha=0.7,
        # label=label,
        elinewidth=0.5,
        capsize=2.5,
        capthick=0.5,
    )

fig.suptitle("Source Count Density")

ax.set_ylabel("$S^{5/2}n \;\;(\mathrm{sr}^{-1}\mathrm{Jy}^{1.5})$")
ax.set_xlabel("$S\;\;(\mathrm{Jy})$")

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)
ax.set_ylim(bottom=10**0)
ax.legend()

fig.show()

# %%
# Same plot but with peak flux and no scaling:

from analysis.stats_utils import err_poisson

color_dict = {
    "Sky Map": "tab:blue",
    "LoTSS-DR2": "tab:orange",
    "Sky Model": "tab:green",
    "Sky Model (matched)": "tab:green",
    "TRECS": "tab:red",
}


S_map = map_cat["Total_flux"].values
S_model = cat["Total_flux"].values
S_model_matched = cat["Total_flux"][idx_model][total_mask].values
S_lofar = lofar_cat["Total_flux"].values * 1e-3
S_trecs = trecs_cat["I144"].values * 1e-3

F_map = map_cat["Peak_flux"].values
F_model = cat["Peak_flux"].values
F_model_matched = cat["Peak_flux"][idx_model][total_mask].values
F_lofar = lofar_cat["Peak_flux"].values * 1e-3
# S_trecs = trecs_cat["I144"].values * 1e-3


fig, axs = plt.subplots(2, 1, figsize=(8, 11), constrained_layout=True, dpi=120)

plot_dict = {
    "Sky Map": S_map,
    "LoTSS-DR2": S_lofar,
    "Sky Model": S_model,
    "Sky Model (matched)": S_model_matched,
    "TRECS": S_trecs,
}

ax = axs[0]
for label, S in plot_dict.items():

    counts, bins = np.histogram(S, bins=np.logspace(-6, 1, 100), density=False)
    err_lo, err_hi = err_poisson(counts)

    def scale_counts_fpeak(counts, bins, area_degsq=25):
        bin_centers = (bins[1:] + bins[:-1]) / 2
        bin_width = bins[1:] - bins[:-1]
        norm_counts = counts.astype(np.float64) # / bin_width # * bin_centers ** (5 / 2)  # Jy**1.5
        norm_counts *= 1 / (area_degsq * (np.pi / 180) ** 2)  # Jy**1.5 / sr
        return norm_counts

    scale_kw = dict(bins=bins, area_degsq=(5634 if label == "LoTSS-DR2" else 25))

    counts_sc = scale_counts_fpeak(counts, **scale_kw)
    err_lo_sc = scale_counts_fpeak(err_lo, **scale_kw)
    err_hi_sc = scale_counts_fpeak(err_hi, **scale_kw)

    color = color_dict[label]

    p = ax.stairs(
        counts_sc,
        bins,
        label=label,
        color=color,
        ls="--" if label == "Sky Model" else "-",
    )
    ax.errorbar(
        (bins[1:] + bins[:-1]) / 2,
        counts_sc,
        yerr=(err_lo_sc, err_hi_sc),
        ls="none",
        color=p.get_edgecolor(),
        alpha=0.7,
        # label=label,
        elinewidth=0.5,
        capsize=2.5,
        capthick=0.5,
    )

ax.set_ylabel("$N \;\;(\mathrm{sr}^{-1})$")
ax.set_xlabel("$Integrated Flux\;\;(\mathrm{Jy})$")

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)
ax.set_xlim(left=10**-5, right=10**-1)
ax.set_ylim(bottom=10**3)
ax.legend()

plot_dict = {
    "Sky Map": F_map,
    "LoTSS-DR2": F_lofar,
    "Sky Model": F_model,
    "Sky Model (matched)": F_model_matched,
    # "TRECS": S_trecs,
}

ax = axs[1]
for label, S in plot_dict.items():

    counts, bins = np.histogram(
        S,
        bins=np.logspace(-6, 1, 100), density=False)
    err_lo, err_hi = err_poisson(counts)

    def scale_counts_fpeak(counts, bins, area_degsq=25):
        bin_centers = (bins[1:] + bins[:-1]) / 2
        bin_width = bins[1:] - bins[:-1]
        norm_counts = counts.astype(np.float64) # / bin_width # * bin_centers ** (5 / 2)  # Jy**1.5
        norm_counts *= 1 / (area_degsq * (np.pi / 180) ** 2)  # Jy**1.5 / sr
        return norm_counts

    scale_kw = dict(bins=bins, area_degsq=(5634 if label == "LoTSS-DR2" else 25))

    counts_sc = scale_counts_fpeak(counts, **scale_kw)
    err_lo_sc = scale_counts_fpeak(err_lo, **scale_kw)
    err_hi_sc = scale_counts_fpeak(err_hi, **scale_kw)

    color = color_dict[label]

    p = ax.stairs(
        counts_sc,
        bins,
        label=label,
        color=color,
        ls="--" if label == "Sky Model" else "-",
    )
    ax.errorbar(
        (bins[1:] + bins[:-1]) / 2,
        counts_sc,
        yerr=(err_lo_sc, err_hi_sc),
        ls="none",
        color=p.get_edgecolor(),
        alpha=0.7,
        # label=label,
        elinewidth=0.5,
        capsize=2.5,
        capthick=0.5,
    )

ax.set_title("Peak Flux")
ax.set_ylabel("$N \;\;(\mathrm{sr}^{-1})$")
ax.set_xlabel("$Peak Flux\;\;(\mathrm{Jy/beam})$")

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)
ax.set_xlim(left=10**-5, right=10**-1)
ax.set_ylim(bottom=10**3)
ax.legend()

fig.show()

# %%
(5634 * (np.pi / 180) ** 2)

# %% [markdown]
# ## Histograms

# %%
import plotting.plot_utils as pltu

reload(pltu)


# Histogram normalized so total number of counts is 1
def norm_hist(data, bins):
    counts, _ = np.histogram(data, bins=bins)
    counts = counts / counts.sum()
    return counts, bins


def plot_norm_hist(ax, data, bins, hist_kwargs={}, **plot_kwargs):
    counts, _ = norm_hist(data, bins, **hist_kwargs)
    ax.stairs(counts, bins, **plot_kwargs)

# %%
# Plot some distributions from all PyBDSF catalogs
import numpy as np
reload(pltu)

get_copy = lambda cat, key: cat[key].values.copy()

extraction_dict = {  # key: (getter, type)
    "Integrated Flux": (lambda cat: get_copy(cat, 'Total_flux'), 'flx',),
    "Peak Flux": (lambda cat: get_copy(cat, 'Peak_flux'), 'flx',),
    # "Peak / Int. Flux": (lambda cat: get_copy(cat, 'Peak_flux') / get_copy(cat, 'Total_flux'), '',),
    # "S/N": (lambda cat: get_copy(cat, 'Total_flux') / get_copy(cat, 'E_Total_flux'), '',),
    "Major Axis":(lambda cat: get_copy(cat, 'Maj'), 'ang',),
}


def extract_data(key):
    getter, typ = extraction_dict[key]
    out = {cat_name: getter(cat) for cat_name, cat in bdsf_catalog_dict.items()}

    # Some quantities of our data need to be scaled to match the LoTSS catalog:
    # - Flux is in Jy for our data and mJy for LoTSS
    # - Angles are in deg for our data and arcsec for LoTSS
    def scale_data(out, c):
        for cat_name in out.keys():
            if cat_name != "LoTSS":
                out[cat_name] *= c

    if typ == 'flx':
        scale_data(out, 1e3)
    
    if typ == 'ang':
        scale_data(out, 3600)
    
    return out

fig, axs = plt.subplots(len(extraction_dict), 1, figsize=(8, 5 * len(extraction_dict)), dpi=150)

# For all plots:
n_bins = 100


for i, (key, getter) in enumerate(extraction_dict.items()):
    ax = axs[i]

    # Extract data from catalogs
    data = extract_data(key)
    bins = pltu.auto_log_bins(list(data.values()), n_bins)

    for cat_name, vals in data.items():
        # ax.hist(vals, label=cat_name, bins=bins, ls=('--' if cat_name == 'Sky Model' else '-'), **kwargs)
        # plot_norm_hist(ax, vals, bins, label=cat_name, ls=('--' if cat_name == 'Sky Model' else '-'))
        counts, _ = np.histogram(vals, bins=bins)
        pltu.add_distribution_plot(counts, bins, ax, label=cat_name, auto_xlim=False, ls=('--' if cat_name == 'Sky Model' else '-'),
                                   color=colors_dict[cat_name], label_count=False)

    ax.legend()
    ax.grid(alpha=0.3)
    ax.set_xscale('log')
    ax.set_yscale('log')
    xlabel = ' '.join([s.capitalize() for s in key.split("_")])

    if i == 0:
        # ax.set_xlim(left=1e-3)
        xlabel += " (mJy)"

    elif i == 1:
        ax.set_xlim(left=1e-2)
        xlabel += " (mJy/beam)"

    elif i == 2:
        ax.set_xlim(left=1)
        xlabel += " (arcsec)"

    ax.set_xlabel(xlabel)
    ax.set_ylabel("Norm. Counts")

# %matplotlib inline
fig.show()

# %%
2 / len(map_cat)

# %%
from astropy.stats import poisson_conf_interval

poisson_conf_interval(1, interval="frequentist-confidence") / len(map_cat)

# %%
# Only TRECS input and PyBDSF output
def auto_range_data(data):
    # Get min and max for logspace based on data
    mn, mx = data.min(), data.max()
    out = (np.floor(np.log10(mn)), np.ceil(np.log10(mx)))

    return out


f_map = map_cat["Total_flux"] * 1e3
f_model = cat["Total_flux"] * 1e3
f_trecs = trecs_cat["I144"]


fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# For all plots:
kwargs = {
    "bins": np.logspace(
        *auto_range_data(np.concatenate([f_map, f_trecs, f_model])), num=100
    ),
    # "bins": np.logspace(0, 5, 100),
    "histtype": "step",
    "log": True,
    "density": False,
}

ax.hist(f_map, label="Simulated Map", color="tab:blue", **kwargs)
ax.hist(f_model, label="Sky Model", color="tab:green", ls="--", **kwargs)
ax.hist(f_trecs, label="TRECS Input", color="tab:red", **kwargs)

ax.legend()
ax.grid(alpha=0.3)
ax.set_xscale("log")

ax.set_xlabel("Integrated Flux [mJy]")
ax.set_ylabel("Counts")
ax.set_xlim(1e-5, 1e4)

fig.show()

# %%
# Load training data catalogs
import pandas as pd

mask_cat = pd.read_hdf(paths.LOFAR_SUBSETS["prototypes"], key="mask_metadata")

ptypes_cat = pd.read_hdf(paths.LOFAR_SUBSETS["prototypes"], key="catalog")

lofar_res_cat = pd.read_csv(paths.LOFAR_RES_CAT)

# %%
# Compare Maj between Map and LOFAR
maj_map = map_cat["Maj"] * 3600
maj_model = cat["Maj"] * 3600
maj_lofar = lofar_cat["Maj"]
lum_thr = 0  # 10**25
maj_lofar_res = lofar_res_cat[lofar_res_cat["L_144"] > lum_thr]["LAS"]
size_trecs = trecs_cat[trecs_cat["RadioClass"] == 6]["size"]
size_mask = mask_cat["feret_diameter_max"]
las_ptypes = ptypes_cat["LAS"]

fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# For all plots:
bins = np.logspace(0, 3.1, 100)
# bins =  np.linspace(0.1, 250, 250)

plot_norm_hist(ax, maj_map, bins, label="Simulated Map")
plot_norm_hist(ax, np.sqrt(maj_lofar**2 + 6**2), bins, label="LoTSS Catalog")
plot_norm_hist(ax, maj_model, bins, label="Sky Model", ls="--")
# plot_norm_hist(ax, size_trecs, bins, label="TRECS Input")
# plot_norm_hist(ax, size_mask / 1.5, bins, label="Training Data Masks")
# plot_norm_hist(ax, las_ptypes, bins, label="Training Data LAS")
# plot_norm_hist(ax, maj_lofar_res, bins, label="LoTSS Resolved")

ax.legend()
ax.grid(alpha=0.3)
ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("DC_Maj [arcsec]")
ax.set_ylabel("Norm. Counts")

ax.set_xlim(1, 2e3)

fig.show()

# %%
# Plot trecs size distribution for extended and compact separately
size_trecs_comp = trecs_cat[trecs_cat["RadioClass"] < 6]["size"]
size_trecs_ext = trecs_cat[trecs_cat["RadioClass"] == 6]["size"]

fig, ax = plt.subplots(1, 1, figsize=(8, 5))

bins = np.logspace(-5, 4, 100)

plot_norm_hist(ax, size_trecs_comp, bins=bins, label="TRECS Compact")
plot_norm_hist(ax, size_trecs_ext, bins=bins, label="TRECS Extended")

ax.legend()
ax.grid(alpha=0.3)
ax.set_xscale("log")
ax.set_yscale("log")

ax.set_xlabel("Size[arcsec]")
ax.set_ylabel("Norm. Counts")

fig.show()

# %%
from astropy.io import fits

# Get info from trecs table
with fits.open(trecs_file) as hdul:
    trecs_info = hdul[1].header
trecs_info

# %%
classes = {1: "late-type", 2: "spheroidal", 3: "lensed spheroidal"}


def xlim_pretty(ax, xmin, xmax):
    dx = 1e-2 * (xmax - xmin)
    ax.set_xlim(xmin - dx, xmax + dx)


def ylim_pretty(ax, ymin, ymax):
    dy = 1e-2 * (ymax - ymin)
    ax.set_ylim(ymin - dy, ymax + dy)


fig, axs = plt.subplots(3, 2, figsize=(12, 12), constrained_layout=True)

for flag, class_name in classes.items():
    subclass_cat = trecs_cat[trecs_cat["RadioClass"] == flag]

    s = subclass_cat["size"]
    bmin, bmaj = subclass_cat["bmin"], subclass_cat["bmaj"]
    e = np.sqrt(bmin**2 + bmaj**2)
    ax_ratio = subclass_cat["axis ratio"]

    ax = axs[0][0]
    ax.scatter(bmin, bmaj, s=1, label=class_name)
    ax.plot([0, 200], [0, 200], "r--")
    ax.plot([0, 200], [0, 200 / 0.5], "r--")
    ax.plot([0, 200], [0, 200 / 0.2], "r--")
    xlim_pretty(ax, 0, 20)
    ylim_pretty(ax, 0, 40)

    ax.set_xlabel("Bmin [arcsec]")
    ax.set_ylabel("Bmaj [arcsec]")

    ax = axs[1][0]
    ax.hist(ax_ratio, bins=100, histtype="step", label=class_name, density=True)
    ax.set_xlabel("Axis Ratio")

    ax = axs[2][0]
    ax.hist(bmaj, bins=np.logspace(-2, 3, 100), density=True, histtype="step")
    ax.set_xscale("log")

    ax = axs[0][1]
    ax.scatter(s, bmaj, s=1, label=class_name)
    ax.plot([0, 200], [0, 200], "r--")
    xlim_pretty(ax, 0, 40)
    ylim_pretty(ax, 0, 80)
    ax.set_xlabel("Size [arcsec]")
    ax.set_ylabel("Bmaj [arcsec]")

    ax = axs[1][1]
    ax.scatter(s, bmin, s=1, label=class_name)
    ax.plot([0, 200], [0, 200], "r--")
    xlim_pretty(ax, 0, 40)
    ylim_pretty(ax, 0, 80)
    ax.set_xlabel("Size [arcsec]")
    ax.set_ylabel("Bmin [arcsec]")

    ax = axs[2][1]
    ax.scatter(s, np.sqrt(ax_ratio) * bmaj, s=1, label=class_name)
    xlim_pretty(ax, 0, 80)
    ylim_pretty(ax, 0, 80)

for ax in axs.flatten():
    ax.legend()
    ax.grid(alpha=0.3)

# %%
# Plot size distribution for all classes
class_dict = {
    1: "late-type",
    2: "spheroidal",
    3: "lensed spheroidal",
    4: "FSRQ",
    5: "BL Lac",
    6: "SS-AGN",
}

fig, axs = plt.subplots(4, 1, figsize=(8, 16), sharex=True, tight_layout=True)

# Plot TRECS data
for key, pop_name in class_dict.items():
    sub_cat = trecs_cat[trecs_cat["RadioClass"] == key]

    if key <= 3:
        ax = axs[0]
        ax.set_title("SFGs:")
        size = sub_cat["bmaj"]
        bins = np.logspace(-1, 2.1, 100)

    else:
        ax = axs[1]
        ax.set_title("AGNs:")
        size = sub_cat["size"]
        bins = np.logspace(-5, 5, 100)

    ax.hist(size, bins=bins, histtype="step", label=pop_name, density=False)


# Plot LoTSS data for comparison
ax = axs[2]
ax.set_title("LoTSS:")
ax.hist(
    lofar_cat["DC_Maj"] * 2,
    bins=np.logspace(-1, 4, 100),
    histtype="step",
    label="LoTSS",
    density=False,
)
agn_cut = lofar_res_cat["L_144"] > 10**25
ax.hist(
    lofar_res_cat[agn_cut]["LAS"],
    bins=np.logspace(-1, 4, 100),
    histtype="step",
    label="LoTSS AGN Lum. Cut",
    density=False,
)

# Plot simulated map results for comparison
ax = axs[3]
ax.set_title("Simulation:")
ax.hist(
    cat["DC_Maj"] * 2 * 3600,
    bins=np.logspace(-1, 4, 100),
    histtype="step",
    label="Sky Model",
    density=False,
)
ax.hist(
    map_cat["DC_Maj"] * 2 * 3600,
    bins=np.logspace(-1, 4, 100),
    histtype="step",
    label="Simulated Map",
    density=False,
)


axs.flatten()[-1].set_xlabel("Size [arcsec]")
for ax in axs:
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.legend()
    ax.grid(alpha=0.3)

    ax.set_ylabel("Counts")

fig.show()

# %%
# Scatter size vs flux for all catalogs
fig, ax = plt.subplots(1, 1, figsize=(10, 8), constrained_layout=True, sharex=True)

# Plot TRECS data
sizes = trecs_cat["size"].values
sfg_flag = trecs_cat["RadioClass"] <= 3
sizes[sfg_flag] = trecs_cat["bmaj"].values[sfg_flag]
fluxes = trecs_cat["I144"]
ax.scatter(sizes, fluxes, s=1, label="TRECS")

# Plot LoTSS data for comparison
sizes = lofar_cat["DC_Maj"].values
fluxes = lofar_cat["Total_flux"].values
ax.scatter(sizes, fluxes, s=1, label="LoTSS")

# Plot sky model results for comparison
sizes = cat["DC_Maj"].values * 3600
fluxes = cat["Total_flux"].values * 1e3
ax.scatter(sizes, fluxes, s=1, label="Sky Model")

# Plot simulated map results for comparison
sizes = map_cat["DC_Maj"].values * 3600
fluxes = map_cat["Total_flux"].values * 1e3
ax.scatter(sizes, fluxes, s=1, label="Simulated Map")


ax.set_xscale("log")
ax.set_yscale("log")
ax.legend()
ax.grid(alpha=0.3)

ax.set_xlabel("Size [arcsec]")
ax.set_ylabel("Flux [mJy]")

fig.show()

# %% [markdown]
# ## Major Iterations Comparison Experiment

# %%
from astropy.table import Table
from tqdm import tqdm

map_name = "map_5deg_v2"
majit_parent = paths.SKY_MAP_PARENT / map_name / "bdsf_majit"
get_iter = lambda x: int(x.name.split(".")[1].split("_")[1])
cat_files = sorted(list(majit_parent.glob("*/catalogues/*srl.FITS")), key=get_iter)

cat_dict = {
    f"Maj.It. {get_iter(f)}": Table.read(f).to_pandas() for f in tqdm(cat_files)
}

print(cat_dict.keys())

# %%
# Add LoTSS DR2 cat to cat dict
lofar_cat = Table.read(paths.LOTSS_DR2_CAT).to_pandas()
cat_dict["LoTSS"] = lofar_cat
print(cat_dict.keys())

# %%
# Plot some distributions from all PyBDSF catalogs
import numpy as np
from maps.map_utils import beam_solid_angle

get_copy = lambda cat, key: cat[key].values.copy()

extraction_dict = {  # key: (getter, type)
    "Integrated Flux": (lambda cat: get_copy(cat, 'Total_flux'), 'flx',),
    "Peak Flux": (lambda cat: get_copy(cat, 'Peak_flux'), 'flx',),
    "S/N": (lambda cat: get_copy(cat, 'Total_flux') / get_copy(cat, 'E_Total_flux'), '',),
    "Major Axis":(lambda cat: get_copy(cat, 'DC_Maj'), 'ang',),
}

def extract_data(key):
    getter, typ = extraction_dict[key]
    out = {cat_name: getter(cat) for cat_name, cat in cat_dict.items()}

    # Some quantities of our data need to be scaled to match the LoTSS catalog:
    # - Flux is in Jy for our data and mJy for LoTSS
    # - Angles are in deg for our data and arcsec for LoTSS
    def scale_data(out, c):
        for cat_name in out.keys():
            if cat_name != "LoTSS":
                out[cat_name] *= c

    if typ == 'flx':
        scale_data(out, 1e3)# * beam_solid_angle(6))
    
    if typ == 'ang':
        scale_data(out, 3600)
    
    return out

# Function to automatically identify plot range for given key word
def auto_log_range(data):
    # Combine data from both catalogs
    data = np.concatenate(data).flatten()

    # Remove zero values
    data = data[data != 0]

    # Get min and max for logspace based on data
    mn, mx = data.min(), data.max()
    # We want to round to the first decimal, but still round up and down for 
    # the min and max values respectively. This is done by multiplying by 10.
    out = (np.floor(np.log10(mn)*10)/10, np.ceil(np.log10(mx)*10)/10)

    return out




fig, axs = plt.subplots(len(extraction_dict), 1, figsize=(8, 5 * len(extraction_dict)))

# For all plots:
n_bins = 100

from matplotlib import colormaps as cm

colors = list(cm['plasma'](np.linspace(0, 1, len(cat_dict)-1)))
colors.append('orange')


for i, (key, getter) in enumerate(extraction_dict.items()):
    ax = axs[i]

    # Extract data from catalogs
    data = extract_data(key)

    # Set range for log hist
    rng = auto_log_range(list(data.values()))
    bins = np.logspace(*rng, num=n_bins)

    for j, (cat_name, vals) in enumerate(data.items()):
        # ax.hist(vals, label=cat_name, bins=bins, ls=('--' if cat_name == 'Sky Model' else '-'), **kwargs)
        plot_norm_hist(ax, vals, bins, label=cat_name, ls=('--' if cat_name == 'Sky Model' else '-'), color=colors[j])

    ax.legend()
    ax.grid(alpha=0.3)
    ax.set_xscale('log')
    ax.set_yscale('log')

    ax.set_xlabel(' '.join([s.capitalize() for s in key.split("_")]))
    ax.set_ylabel("Norm. Counts")

# %matplotlib inline
fig.show()

# %%
from scipy.ndimage import gaussian_filter
from maps.map_utils import beam_solid_angle
import numpy as np

# Sanity check: compare manual restored image with actual resored image
map_name = "map_5deg_v2"
ddf_parent = paths.SKY_MAP_PARENT / "map_5deg_v2" / "ddf"
orig_restored = get_image(ddf_parent / "map_5deg_v2.int.restored.fits")[0].squeeze()
orig_residual = get_image(ddf_parent / "map_5deg_v2.int.residual.fits")[0].squeeze()
orig_convmodel = get_image(ddf_parent / "map_5deg_v2.int.convmodel.fits")[0].squeeze()

model = get_image(ddf_parent / "map_5deg_v2.model10.fits")[0].squeeze()
residual = get_image(ddf_parent / "map_5deg_v2.residual10.fits")[0].squeeze()
smoothNorm = get_image(ddf_parent / "map_5deg_v2.MeanSmoothNorm.fits")[0].squeeze()
norm = get_image(ddf_parent / "map_5deg_v2.Norm.fits")[0].squeeze()
normFacets = get_image(ddf_parent / "map_5deg_v2.NormFacets.fits")[0].squeeze()

# Get resroring beam sigma
beam_FWHM = 4  # 6 arcsec = 4 pixels
beam_sigma = beam_FWHM / (2 * np.sqrt(2 * np.log(2)))
# Convolve model_arr with gaussian
# Multiply by sqrt(norm) / sqrt(SmoothNorm)
convmodel = (
    gaussian_filter(model, beam_sigma, mode="constant", truncate=10)
    * beam_solid_angle(6)
    * np.sqrt(norm)
    / np.sqrt(smoothNorm)
    / 1.5**2
)


# Make restored image
restored = convmodel + residual / np.sqrt(smoothNorm)

# %%
import plotting.map_plots as mpplt

# %matplotlib widget
mpplt.double_map_plot(
    orig_convmodel,
    convmodel,
    minmax=False,
    size=(14, 7),
)

# %%
ratio = np.full_like(orig_convmodel, np.nan)
np.divide(orig_convmodel, convmodel, out=ratio, where=convmodel != 0)

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

ax.hist(ratio.flatten(), histtype="bar", log=True, bins=np.linspace(0, 10, 100))

ax.grid(alpha=0.3)
fig.show()

# %%
# Plot pixel distributions
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

kwars = dict(histtype="step", log=True, bins=100)  # np.linspace(0, 0.01, 100))

ax.hist(orig_convmodel.flatten(), label="Original ConvModel", **kwars)
ax.hist(convmodel.flatten(), label="ConvModel", **kwars)

ax.legend()
ax.grid(alpha=0.3)

fig.show()

# %%
reload(mpplt)
from matplotlib.colors import Normalize

resid_ratio = residual / orig_residual
mn, mx = (np.nanmin(resid_ratio), np.nanmax(resid_ratio))
print(mn, mx)
resid_ratio_minmax = (resid_ratio - mn) / (mx - mn)

# %matplotlib inline
mpplt.double_map_plot(
    resid_ratio,
    np.sqrt(smoothNorm),
    norm_quantile=None,
    norm=(Normalize(vmin=0, vmax=1),)*2,
)

# %%
np.nanmin(resid_ratio)

# %% [markdown]
# ## PyBDSF Residual RMS

# %%
map_name = "map_5deg_v4"
bdsf_dir = paths.SKY_MAP_PARENT / map_name / f"ddf/{map_name}.int.restored_pybdsf"

# %%
resid_file = bdsf_dir / f"residual/{map_name}.int.restored.pybdsf.resid_gaus.fits"
resid_map = get_image(resid_file, get_wcs=False)

wav_resid_file = (
    bdsf_dir / f"wavelet/residual/{map_name}.int.restored.pybdsf.resid_wavelets.fits"
)
# wav_resid_map = get_image(wav_resid_file, get_wcs=False)

ddf_resid_map = get_image(
    paths.SKY_MAP_PARENT / map_name / f"ddf/{map_name}.int.residual.fits", get_wcs=False
)

# %%
import plotting.map_plots as mpplt

# %matplotlib widget
mpplt.double_map_plot(
    resid_map,
    ddf_resid_map,
    norm_quantile=None,
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 5))

kwargs = dict(histtype="step", log=True, bins=100)

axs[0].hist(resid_map.flatten(), label="Gaussian", **kwargs)
axs[1].hist(wav_resid_map.flatten(), label="Wavelet", **kwargs)

for ax in axs.flatten():
    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
# RMS of Gaussian residual
rms_resid = np.sqrt(np.nanmean(resid_map**2))
print(f"RMS of Gaussian residual: {rms_resid:.2e}")

# RMS of Wavelet residual
# rms_wav_resid = np.sqrt(np.nanmean(wav_resid_map**2))
# print(f"RMS of Wavelet residual: {rms_wav_resid:.2e}")

# RMS of DDF residual
rms_ddf_resid = np.sqrt(np.nanmean(ddf_resid_map**2))
print(f"RMS of DDF residual: {rms_ddf_resid:.2e}")

# %%
# RMS of Gaussian residual
rms_resid = np.sqrt(np.nanmean(resid_map**2))
print(f"RMS of Gaussian residual: {rms_resid:.2e}")

# RMS of Wavelet residual
# rms_wav_resid = np.sqrt(np.nanmean(wav_resid_map**2))
# print(f"RMS of Wavelet residual: {rms_wav_resid:.2e}")

# RMS of DDF residual
rms_ddf_resid = np.sqrt(np.nanmean(ddf_resid_map**2))
print(f"RMS of DDF residual: {rms_ddf_resid:.2e}")

# %%
# Split image into 25 guadrants (1x1 deg each) and get rms for each
def quadrants_rms(image, n=5):
    image = image.squeeze()
    quad_shape = (image.shape[0] // n, image.shape[1] // n)

    rms = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            quad = image[
                i * quad_shape[0] : (i + 1) * quad_shape[0],
                j * quad_shape[1] : (j + 1) * quad_shape[1],
            ]
            rms[i, j] = np.sqrt(np.nanmean(quad**2))
    return rms


quad_rms = quadrants_rms(ddf_resid_map * 1e3, n=10)

# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

fig.colorbar(ax.imshow(quad_rms, origin="lower"))
ax.axis("off")

fig.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6), dpi=200)

ax.hist(quad_rms.flatten(), bins=10, histtype="stepfilled", color="darkblue")
ax.set_xlabel("RMS [mJy/beam]")
ax.set_ylabel("# Quadrants")
ax.grid(alpha=0.3)

# %% [markdown]
# # Look at Map

# %%
from astropy.io import fits
import utils.paths as paths
from plotting.map_plots import plot_sky_map
from matplotlib.colors import SymLogNorm
import numpy as np
from maps.map_utils import get_image, beam_solid_angle

map_name = "map_verif_v1"

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"

image, wcs = get_image(sky_model_file)
# Convert to mJy/beam
image *= beam_solid_angle(6) / 1.5**2 * 1e3

clip_quantile = 0.999
vmin = np.quantile(image[image < 0], clip_quantile)
vmax = np.quantile(image[image > 0], clip_quantile)
# Base linthr on max. tile RMS value of 0.153 mJy/beam
rms = 0.153
linthresh = 1.0 * rms
norm_kw = dict(linthresh=linthresh, vmin=vmin, vmax=vmax, clip=True)
norm_map = SymLogNorm(**norm_kw)

# %matplotlib widget
plot_sky_map(
    image,
    wcs=wcs,
    norm=norm_map,
)
# Out:
# (<Figure size 900x900 with 2 Axes>,
#  <WCSAxes: >,
#  <matplotlib.image.AxesImage at 0x7fb5d3b06590>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from astropy.io import fits
import utils.paths as paths
from plotting.map_plots import plot_sky_map

map_name = 'map_5deg_8e-5JyLimit'

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"

image, wcs = get_image(sky_model_file)

# %matplotlib widget

plot_sky_map(
    image,
    wcs = wcs,
    size=(7, 7),
)

# %%
image.shape

# %% [markdown]
# ## DDF-Pipeline PyBDSF Statistics

# %%
from astropy.table import Table
import pandas as pd


def load_srl(map_name):
    file = (
        paths.SKY_MAP_PARENT
        / map_name
        / f"ddf-pipeline/image_dirin_SSD_m.app.restored.pybdsm.srl.fits"
    )
    df = Table.read(file).to_pandas()
    return df


def load_input_catalogs(map_name):
    file = paths.SKY_MAP_PARENT / map_name / f"{map_name}.h5"
    df_comp = pd.read_hdf(file, key="compact_sources_metadata")
    df_ext = pd.read_hdf(file, key="extended_sources_metadata")
    return df_comp, df_ext

# %%
map_name = "map_5deg_8e-5JyLimit"
srl = load_srl(map_name)
df_comp, df_ext = load_input_catalogs(map_name)

# %%
# For comparison, import the LoTSS-DR2 catalog
lofar_cat = paths.LOFAR_DATA_PARENT / "LoTSS_DR2_v110_masked.srl.fits"

with fits.open(lofar_cat) as hdul:
    df_lofar = Table.read(hdul).to_pandas()

# %%
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(12, 7))

bins = np.logspace(-5, 2, 100)
kwargs = dict(histtype="step", bins=bins, density=False)
ax.hist(srl["Total_flux"], label="PyBDSF sources", **kwargs)
ax.hist(
    np.concatenate([df_comp["flux"], df_ext["flux"]]), label="Input sources", **kwargs
)
ax.hist(df_lofar["Total_flux"] * 1e-3, label="LoTSS sources", **kwargs)
# ax.hist(df_comp['flux'], label='Compact sources', **kwargs)
# ax.hist(df_ext['flux'], label='Extended sources', **kwargs)

# Vertical dashed line at 0.03 Jy
ax.axvline(0.03, color="red", linestyle="dashed", label="0.03 Jy")


ax.grid(alpha=0.3)
ax.set_xlabel("Total flux (Jy)")
ax.set_ylabel("Normalized counts")
ax.set_yscale("log")
ax.set_xscale("log")
ax.legend()

fig.show()

# %% [markdown]
# # Simulated Map Details

# %%
from maps.map_maker import MapMaker

map_name = "map_5deg_posCorr"

mm = MapMaker.load(map_name)

# %%
import plotting.map_plots as mpplt
import plotting.image_plots as implt

reload(mpplt)
reload(implt)

# Plot images of extended sources
imgs, masks = mm.ext_data["images"], mm.ext_data["masks"]

fig, axs = implt.random_image_grid(imgs, masks=masks, n_img=49, idx_titles=True)
fig.show()

# %%
idx = 15877

img, dist_mask = imgs[idx], masks[idx]


fig, axs = plt.subplots(1, 2, figsize=(10, 5))

ax = axs[0]
ax.imshow(img)
ax.contour(dist_mask, levels=[0.5], colors="red", alpha=0.5)

ax = axs[1]
ax.imshow(img * (1 - dist_mask))

for ax in axs:
    ax.axis("off")

# %%
# Do the same for compact images
import plotting.map_plots as mpplt
import plotting.image_plots as implt

reload(mpplt)
reload(implt)

# Plot images of extended sources
imgs, masks = mm.comp_images, None

# Normalize
# imgs = imgs / imgs.sum(axis=(1, 2), keepdims=True)

fig, axs = implt.random_image_grid(
    imgs,
    masks=masks,
    n_rows=6,
    n_cols=3,
    n_img=18,
    vmax=None,
)
fig.show()

# %%
imgs[0].sum(), imgs[0].max()

# %%
import maps.map_utils

reload(maps.map_utils)
from maps.map_utils import coord2pix

# Plot source array with same-size cutout of map array around its center
idx = 16

src_img = mm.ext_data["images"][idx]
size = src_img.shape[0]
coords = mm.ext_df.loc[idx, ["x_coord", "y_coord"]].values
x, y = coord2pix(coords, mm.map_size_deg, mm.map_size_px)

# Cutout of map array around source center
x_slice = slice(x - size // 2, x + size // 2)
y_slice = slice(y - size // 2, y + size // 2)
cutout = mm.map_array[x_slice, y_slice]

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(src_img)
axs[1].imshow(cutout)

fig.show()

# %%
map_size_deg = mm.map_size_deg
map_size_px = (mm.map_size_px,) * 2

# Plot source array with same-size cutout of map array around its center
idx = 16

source_arr = mm.ext_data["images"][idx]
size = src_img.shape[0]
coords = mm.ext_df.loc[idx, ["x_coord", "y_coord"]].values
centroid = mm.ext_df.loc[idx, ["centroid-0", "centroid-1"]].values.astype(int)

x_px, y_px = coord2pix(coords, map_size_deg, map_size_px)

# Set centroid coords (relative to source array)
x_c, y_c = (
    centroid
    if centroid is not None
    else (source_arr.shape[0] // 2, source_arr.shape[1] // 2)
)

# Determine slices for adding source to map
x_slice = slice(x_px - x_c, x_px - x_c + source_arr.shape[0])
y_slice = slice(y_px - y_c, y_px - y_c + source_arr.shape[1])

# Check if source is within map, otherwise correct slice to fit
# and reduce source_arr accordingly
if x_slice.start < 0:
    source_arr = source_arr[-x_slice.start :, :]
    x_slice = slice(0, x_slice.stop)
if x_slice.stop > map_size_px[0]:
    source_arr = source_arr[: map_size_px[0] - x_slice.stop, :]
    x_slice = slice(x_slice.start, map_size_px[0])
if y_slice.start < 0:
    source_arr = source_arr[:, -y_slice.start :]
    y_slice = slice(0, y_slice.stop)
if y_slice.stop > map_size_px[1]:
    source_arr = source_arr[:, : map_size_px[1] - y_slice.stop]
    y_slice = slice(y_slice.start, map_size_px[1])

x_slice, y_slice

# %%
mm.map_array[x_slice, y_slice]

# %%
mm.ext_df

# %% [markdown]
# # Add channel dim. to fits model

# %%
from astropy.io import fits
import numpy as np
import utils.paths as paths

map_name = "map_5deg_8e-5JyLimit"

# Open fits file
sky_model_file = paths.SKY_MAP_PARENT / map_name / f"{map_name}.fits"
with fits.open(sky_model_file) as hdul:
    image = hdul[0].data
    header = hdul[0].header

# Write new fits file
new_file = sky_model_file.parent / f"{map_name}_chanDim.fits"
fits.writeto(new_file, np.expand_dims(image, 0), header, overwrite=True)

# %%
# Open and check shape of new image
with fits.open(new_file) as hdul:
    image = hdul[0].data
    header = hdul[0].header

image.shape

# %%
image.ndim

# %%
import maps.map_maker

reload(maps.map_maker)
from maps.map_maker import MapMaker

map_name = "map_5deg_posCorr"

mm = MapMaker.load(map_name)

# %%
mm.save_telsim_output()

# %%
mm.save_to_fits()

# %% [markdown]
# # Copy/Rename MS files

# %%
import shutil

map_name = "map_2.5deg_max80_1e-7JyLimit"
map_folder = paths.SKY_MAP_PARENT / map_name
map_ms_folder = map_folder / "ms"
map_ms_folder.mkdir(exist_ok=True)
LoTSS_MS_folder = paths.LOFAR_DATA_PARENT / "LoTSS_MS"

LoTSS_MS_dirs = sorted(list(LoTSS_MS_folder.glob("*ms.archive")))
target_MS_dirs = [
    map_ms_folder / d.name.replace("ms.archive", "MS") for d in LoTSS_MS_dirs
]
LoTSS_bands = [int(d.name.split("MHz")[0].split("_")[-1]) for d in LoTSS_MS_dirs]
target_band_dict = dict(zip(LoTSS_bands, target_MS_dirs))
LoTSS_band_dict = dict(zip(LoTSS_bands, LoTSS_MS_dirs))


def copy_ms_to_map(ms_dir):
    shutil.copytree(ms_dir, map_ms_folder / ms_dir.name.replace("ms.archive", "MS"))


def copy_band_to_map(band):
    ms_dir = LoTSS_band_dict[band]
    shutil.copytree(ms_dir, target_MS_dirs[band])


def activate_band(band):
    ms = target_band_dict[band]
    if ms.exists():
        print(f"Band {band} already activated.")
        return True
    elif (ms_ := ms.with_suffix(".MS_")).exists():
        ms_.rename(ms)
        print(f"Band {band} activated.")
        return True
    else:
        print(f"Band {band} not found.")
        return False


def deactivate_band(band):
    ms = target_band_dict[band]
    ms_ = ms.with_suffix(".MS_")
    if ms.exists():
        ms.rename(ms_)
        print(f"Band {band} deactivated.")
        return True
    elif ms_.exists():
        print(f"Band {band} already deactivated.")
        return True
    else:
        print(f"Band {band} not found.")
        return False


def activate_bands(bands):
    for band in bands:
        activate_band(band)


def activate_bands_between(min, max):
    bands = [band for band in LoTSS_bands if min <= band <= max]
    activate_bands(bands)


def deactivate_bands_between(min, max):
    bands = [band for band in LoTSS_bands if min <= band <= max]
    deactivate_bands(bands)


def deactivate_bands(bands):
    for band in bands:
        deactivate_band(band)


def activate_all_bands():
    for band in LoTSS_bands:
        activate_band(band)


def deactivate_all_bands():
    for band in LoTSS_bands:
        deactivate_band(band)

# %%
activate_all_bands()

# %%
activate_bands_between(142, 146)

# %%
deactivate_band(160)

# %%
from tqdm import tqdm

# Copy all MS
for ms_dir in tqdm(LoTSS_MS_dirs):
    copy_ms_to_map(ms_dir)

# %%
# Copy 6 SB to duplicate folder
duplicate_dir = map_ms_folder.with_name(map_ms_folder.name + "_copy")
for ms_dir in tqdm(target_MS_dirs[2::4]):
    shutil.copytree(ms_dir, duplicate_dir / ms_dir.name)

# %%
import shutil

map_name = "map_2.5deg_max80_1e-7JyLimit"
map_folder = paths.SKY_MAP_PARENT / map_name
synthms_folder = map_folder / "synthms_DP3"
synthms_folder.mkdir(exist_ok=True)

ms_list = sorted(list(synthms_folder.glob("*.MS")))

# %%
[ms.name for ms in ms_list][:5]

# %%
from casacore.tables import table
import numpy as np


def get_mean_freq(ms):
    with table(str(ms) + "/SPECTRAL_WINDOW", ack=False) as t:
        freqs = t.getcol("CHAN_FREQ")[0] * 1e-6  # MHz
    return np.mean(freqs)

# %%
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor, as_completed

DEF_DIR = paths.BASE_PARENT / "src/maps/default_files/synthms"


def copy_ms_to_defdir(ms_dir):
    fmean = get_mean_freq(ms_dir)
    target_name = ms_dir.name.replace(
        ms_dir.stem.split("_")[-1], f"{int(np.round(fmean))}MHz"
    )
    if (DEF_DIR / target_name).exists():
        print(f"MS {target_name} already exists - deleting.")
        shutil.rmtree(DEF_DIR / target_name)
    shutil.copytree(ms_dir, DEF_DIR / target_name)


# Function to process each item
def process_item(ms_dir):
    copy_ms_to_defdir(ms_dir)


# Parallelize the copying operation
with ProcessPoolExecutor() as executor:
    futures = [executor.submit(process_item, ms_dir) for ms_dir in ms_list]
    for future in tqdm(as_completed(futures), total=len(futures)):
        future.result()  # Ensure any exceptions are raised

# %%
from maps.map_utils import lofar_num2nu

ms_list_chunks = [
    [f'"{ms.name}"' for ms in ms_list[(i + 1) : (i + 1) + 10]]
    for i in range(0, 240, 10)
]

for i, chunk in enumerate(ms_list_chunks):
    nu = int(np.round(lofar_num2nu(103 + i * 10, station="HBA")[1] * 1e-6))
    msout_str = f"synth_DP3avg_SB{1 + 10*i:03d}_{nu}MHz.MS"
    print(f"{len(chunk)} files: {msout_str}")
    print("\n".join(chunk))
    print("\n\n")
print(len(ms_list_chunks))

# %% [markdown]
# # Analyse Logs

# %%
labels = [
    "Miscellaneous",
    "Dynspec",
    "Clipcal",
    "Shift",
    "Wide-field KillMS",
    "KillMS phase 60sb",
    "KillMS amp/phase 60sb",
    "KillMS amp/phase full",
    "KillMS amp/phase full 2",
    "Wide-field DDF dirin",
    "Predict wide-field",
    "DDF dirin",
    "DDF phase 60sb",
    "DDF amp-phase 60sb",
    "DDF band images",
    "DDF full NS",
    "DDF full",
    "DDF full low QU",
    "DDF full vlow QU",
    "DDF full V",
    "DDF full low",
    "DDF bootstrap",
    "DDF bootstrap single-band",
    "DDF full DI",
    "DDF full amp-phase",
    "DDF predict",
    "KillMS DIS0",
    "KillMS DDS0",
    "KillMS DIS1",
    "KillMS DDS1",
    "KillMS DIS2",
    "KillMS DDS2",
    "KillMS DDS3",
]
fragments = [
    "***",
    "dynspec",
    "ClipCal",
    "shift",
    "wide_killms_p1",
    "killms_p1",
    "killms_ap1",
    "killms_f_ap1",
    "killms_f_ap2",
    "wide_image_dirin",
    "wide_image_phase1_predict",
    "image_dirin",
    "image_phase1",
    "image_ampphase1",
    "NS_Band",
    "image_full_ampphase_di_m.NS",
    "image_full_ampphase_m",
    "image_full_low_IQU",
    "image_full_vlow_IQU",
    "image_full_high_stokesV",
    "image_full_low",
    "image_bootstrap",
    "image_low",
    "image_full_ampphase_di",
    "image_full_ampphase",
    "DDF-Predict",
    "_DIS0",
    "_DDS0",
    "_DIS1",
    "_DDS1",
    "_DIS2",
    "_DDS2",
    "_DDS3",
]

label_dict = dict(zip(labels, fragments))

# %%
display(label_dict)

# %%
from __future__ import print_function
from builtins import range
from datetime import datetime, timedelta
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import utils.paths as paths



def get_time_range(file):
    lines = open(file).readlines()
    start = datetime.strptime(lines[1][:19], "%Y-%m-%d %H:%M:%S")
    end = datetime.strptime(lines[-2][:19], "%Y-%m-%d %H:%M:%S")
    return (end - start).total_seconds()


map_name = "map_5deg_8e-5JyLimit"
log_dir = paths.SKY_MAP_PARENT / map_name / "ddf-pipeline/logs"
g = [f for f in log_dir.glob("*")]
times = []
for f in g:
    dt = get_time_range(f)
    times.append(dt)


sums = np.zeros(len(labels))
print(len(labels), len(fragments))

# classify each file
for j, f in enumerate(g):
    label = 0
    for i in range(len(labels)):
        if fragments[i] in f.name:
            label = i
            break

    # print(f.name, times[j], labels[label], fragments[label])
    sums[label] += times[j]


# Set up array to store runtimes and label dictionary to store filenames
sums = np.zeros(len(labels))
file_dict = {lbl: [] for lbl in labels}

# Loop through files
for j, f in enumerate(g):

    # Set default label and index
    idx = 0
    label = labels[idx]  # Miscellaneous

    # Loop through labels and fragments to find match
    for i, (lbl, frg) in enumerate(label_dict.items()):

        # If fragment is in filename (i.e. match), set label and index and break
        if frg in f.name:
            idx = i
            label = lbl
            break
        
    # Add time to sum and filename to label dictionary
    sums[idx] += times[j]
    file_dict[label].append(f.name)
            
        

pl = []
ps = []
print("------\n")
print(
    "---------------------------------\n"\
    "Operation         Time (hh:mm:ss)\n"\
    "---------------------------------"
)
for i in range(len(labels)):
    if sums[i]:
       #print("%-25s %7.0f" % (labels[i], sums[i]))
        print(f"{labels[i]:<25} {timedelta(seconds=sums[i])}")
        pl.append(labels[i])
        ps.append(sums[i])

tt = np.sum(sums)
print(
    f"---------------------------------\n\n"\
    f"Total time {timedelta(seconds=tt)}"
)

# compatibility
try:
    cmap = plt.cm.Spectral
except:
    cmap = plt.cm.spectral

colors = cmap(np.linspace(0.1, 1.0, len(pl)))

# %matplotlib inline
fig1, ax1 = plt.subplots()
ax1.pie(ps, labels=pl, autopct="%1.1f%%", colors=colors)
ax1.axis("equal")
plt.show()

# %%
pl

# %%
# Make same plot for KillMS, DDF and Other
killms_labels = [lbl for lbl in pl if "KillMS" in lbl]
ddf_labels = [lbl for lbl in pl if "DDF" in lbl]
other_labels = [lbl for lbl in pl if lbl not in killms_labels + ddf_labels]

killms_sum = np.sum([ps[pl.index(lbl)] for lbl in killms_labels])
ddf_sum = np.sum([ps[pl.index(lbl)] for lbl in ddf_labels])
other_sum = np.sum([ps[pl.index(lbl)] for lbl in other_labels])

pl2 = ["Other", "DDF", "KillMS"]
ps2 = [other_sum, ddf_sum, killms_sum]
colors = colors = cmap(np.linspace(0.1, 1.0, len(pl2)))

fig2, ax2 = plt.subplots()
ax2.pie(ps2, labels=pl2, autopct="%1.1f%%", colors=colors)
ax2.axis("equal")

plt.show()

# %%
# Sort log files by time of modification
sorted_files = [
    f.name
    for f in sorted(g, key=lambda x: x.stat().st_mtime, reverse=True)
    if "DDF-image" in f.name
]
sorted_files

# %% [markdown]
# # Make mask for DDF-Pipeline

# %%
import maps.map_maker

reload(maps.map_maker)
from maps.map_maker import MapMaker

map_name = "map_1deg_max80_1e-7JyLimit"

mm = MapMaker.load(map_name)

# %%
dist_mask, file = mm.make_threshold_mask(sensitivity=1e-4, save=True, mask_size="model")

# %%
mm.save_masked_map(file)

# %%
from plotting.map_plots import double_map_plot

# %matplotlib widget
double_map_plot(
    mm.map_array.squeeze(),
    dist_mask.squeeze(),
    # wcs=(mm.wcs, mm.wcs),
    scale_fn=lambda x: x,
    size=(14, 7),
    minmax=False,
)

# %%
map_folder = Path("/home/bbd0953/diffusion/sky_maps/test_map_80")
sky_model_file = map_folder / "test_map_80.fits"

from astropy.io import fits
from astropy.wcs import WCS


def get_image(file, get_wcs=True):
    hdul = fits.open(file)
    image = hdul[0].data
    if get_wcs:
        wcs = WCS(hdul[0].header, naxis=2)
        return image, wcs
    else:
        return image

# %%
import plotting.map_plots as mpplt
reload(mpplt)

data_arr, data_wcs = get_image(sky_model_file)

# %matplotlib widget
mpplt.plot_sky_map(data_arr, wcs=data_wcs, scale_fn=lambda x: x)

# %% [markdown]
# # Compare TRECS / LOFAR / TGSS

# %%
from astropy.io import fits

import pandas as pd
import h5py

trecs_catalog = paths.BASE_PARENT / "trecs_output/5deg/catalogue_continuum_wrapped.fits"


with fits.open(trecs_catalog) as hdul:
    df_trecs = pd.DataFrame(hdul[1].data)

# df_trecs

# %%
from astropy.io import fits

import pandas as pd
import h5py

trecs_flim_catalog = (
    paths.BASE_PARENT / "trecs_output/5deg_8e-5JyLimit/catalogue_continuum_wrapped.fits"
)


with fits.open(trecs_flim_catalog) as hdul:
    df_trecs_flim = pd.DataFrame(hdul[1].data)

# %%
tgss_catalog = Path(
    "/hs/fs08/data/group-brueggen/tmartinez/ddf-pipeline/catalogs/TGSSADR1_7sigma_catalog.fits"
)

with fits.open(tgss_catalog) as hdul:
    df_tgss = pd.DataFrame(hdul[1].data)

# %%
import pandas as pd
import utils.paths as paths

lofar_cat = paths.LOFAR_DATA_PARENT / "LoTSS_DR2_v110_masked.srl.fits"

with fits.open(lofar_cat) as hdul:
    df_lofar = pd.DataFrame(hdul[1].data)

# %%
# Plot all together
fig, axs = plt.subplots(1, 1, figsize=(8, 6), tight_layout=True)

fig.suptitle("All Catalogs")

bins = np.linspace(0, 1, 100)
bins = np.logspace(0, 5, 100)
axs.set_xscale("log")
alpha = 0.7

plot_all = False

ax = axs
if plot_all:
    ax.hist(
        df_trecs["I144"],
        bins=bins,
        alpha=alpha,
        label="TRECS Default",
        density=True,
        histtype="step",
    )
ax.hist(
    df_trecs_flim["I144"],
    bins=bins,
    alpha=alpha,
    label="TRECS Min Flux",
    density=True,
    histtype="step",
)
if plot_all:
    ax.hist(
        df_tgss["Total_flux"],
        bins=bins,
        alpha=alpha,
        label="TGSS",
        density=True,
        histtype="step",
    )
ax.hist(
    df_lofar["Total_flux"],
    bins=bins,
    alpha=alpha,
    label="LOFAR",
    density=True,
    histtype="step",
)

ax.set_xlabel("Total Flux (mJy)")
ax.set_yscale("log")
ax.grid(alpha=0.3)
ax.legend()

fig.show()

# %%
(df_trecs_flim["I144"]).min()

# %%
df_lofar["Total_flux"].min()

# %%
# LOFAR resolved catalog
import pandas as pd
import utils.paths as paths

df_lofar_res = pd.read_csv(paths.LOFAR_RES_CAT)

# %%
# Scatter plot total flux vs LAS

fig, ax = plt.subplots(1, 1, figsize=(6, 6), tight_layout=True)

ax.scatter(df_lofar_res["Total_flux"], df_lofar_res["LAS"], s=1)
ax.set_xlabel("Total Flux (mJy)")
ax.set_ylabel("LAS (arcsec)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)

fig.show()

# %% [markdown]
# # Correct source positions

# %%
import maps.map_maker

reload(maps.map_maker)
from maps.map_maker import MapMaker

map_name = "map_5deg_8e-5JyLimit"
mm = MapMaker.load(map_name)

# %%
mm.give_name("map_5deg_posCorr")

# %%
import maps.map_utils

reload(maps.map_utils)

mm.reset_map_array()
mm.make_map(make_sources=False)

# %%
mm.save()

# %%
# Make map-sized mask
_, mask_file = mm.make_threshold_mask(sensitivity=5e-5, save=True, mask_size="model")

# Save masked map
mm.save_masked_map(mask_file)

# Make ddf-sized mask
mm.make_threshold_mask(sensitivity=5e-5, save=True, mask_size="ddf")

# %%
# Compare original sky model and new sky model
import plotting.map_plots as mpplt
reload(mpplt)

map_folder = paths.SKY_MAP_PARENT / map_name
sky_model_file = map_folder / f"{map_name}.fits"
orig_array = get_image(sky_model_file, get_wcs=False)

# %matplotlib widget
mpplt.double_map_plot(
    orig_array,
    mm.map_array.squeeze(),
)

# %% [markdown]
# # Simulated Map Statistics

# %%
from maps.map_maker import MapMaker

map_name = "map_1deg_max80_1e-7JyLimit"

mm = MapMaker.load(map_name)

# %%
import numpy as np

# Peak values of normalized images
ext_peak_vals = np.array([img.max() for img in mm.ext_data["images"]])
comp_peak_vals = np.array([img.max() for img in mm.comp_images])

# %%
ext_flux = mm.ext_df['flux']
comp_flux = mm.comp_df['flux']


# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(12, 6), tight_layout=True)

# ax = axs[0]
ax.scatter(ext_flux, ext_peak_vals * ext_flux, s=1, label='Extended Sources')
ax.set_xscale('log')
ax.set_yscale('log')

# axs[1].scatter(comp_flux, comp_peak_vals * comp_flux, s=1, label='Compact Sources')

# Add unity line
x = np.linspace(ext_flux.min(), ext_flux.max(), 100)
ax.plot(x, x, label='1', color='grey', alpha=0.4, ls='--')
ax.plot(x, 0.9*x, label='0.9', color='grey', alpha=0.4, ls=':')

for ax in [ax]:#axs:
    ax.set_xlabel('Flux (Jy)')
    ax.set_ylabel('Peak Flux (Jy/px)')
    ax.legend()
    ax.grid(alpha=0.3)

fig.show()

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(12, 6), tight_layout=True)

ratio = 1 / ext_peak_vals  # Flux / peak_flux

bin_limit = 0.1
print(bin_limit)
counts, bins, _ = ax.hist(
    ratio,
    bins=np.linspace(1 - bin_limit, 1 + bin_limit, 100),
    log=False,
    density=True,
    histtype="step",
    label="Extended Sources",
)

# Fit gaussian
from scipy.stats import norm
from scipy.optimize import curve_fit

x = (bins[1:] + bins[:-1]) / 2
(mu, std), _ = curve_fit(norm.pdf, x, counts, p0=[1, 0.01])
p = norm.pdf(x, mu, std)
ax.plot(x, p, "k", linewidth=2, label=f"Fit: $\mu$={mu:.2e}, $\sigma$={std:.2e}")

ax.grid(alpha=0.3)
ax.legend()
ax.set_xlabel(r"$F_\mathrm{Sum} / F_\mathrm{Max}$")
ax.set_ylabel("Normalized Counts")

# %%
from matplotlib import colormaps as cm

# Cut off below different int. flux values and look at resulting distribution
# of peak flux values
lotss_limit = np.array([1e-5, 1e-4, 1e-3])  # Jy / beam
F_thr = lotss_limit * 0.055  # Jy / px
gamma_cut = 0.9
S144_threshold = F_thr * gamma_cut
hist_bins = np.logspace(-7, 0, 200)

fig, axs = plt.subplots(2, 1, figsize=(10, 8), tight_layout=True, sharex=True)
colors = cm["Set1"](np.linspace(0, 1, len(F_thr)))

for i, lim in enumerate(lotss_limit):
    clr = colors[i]
    thr = S144_threshold[i]
    S144_cut = ext_flux[ext_flux > thr]
    S144_removed = ext_flux[ext_flux <= thr]
    ratio_cut = len(S144_cut) / len(ext_flux)
    ratio_removed = len(S144_removed) / len(ext_flux)
    axs[0].hist(
        S144_cut,
        bins=hist_bins,
        density=True,
        log=True,
        label=f"Cut: {lim:.0e} Jy/beam - {ratio_cut * 100:.2f}%",
        histtype="step",
        color=clr,
    )
    axs[1].hist(
        S144_removed,
        bins=hist_bins,
        density=True,
        log=True,
        label=f"Removed: {lim:.0e} Jy/beam - {ratio_removed * 100:.2f}%",
        histtype="step",
        color=clr,
    )

    # Vertical line
    for ax in axs:
        ax.axvline(thr, color=clr, ls="--", alpha=0.5)
    # x = (hist_bins[1:] + bins[:-1]) / 2
    # (mu, std), _ = curve_fit(norm.pdf, x, counts, p0=[1, 0.01])
    # p = norm.pdf(x, mu, std)
    # ax.plot(x, p, label=f"Cut: {thr:.0e}")
for ax in axs:
    ax.grid(alpha=0.3)
    ax.legend()
    ax.set_xlabel(r"$S_{144} (Jy)$")
    ax.set_xscale("log")

# %%
ext_flux.min()

# %%
lotss_limit = 1e-4  # mJy/beam
trecs_thr = lotss_limit * 0.055 * 1 / 1.05

# %% [markdown]
# # Plot uv-coverage

# %%
import glob
import sys
import numpy as np
import casacore.tables as pt
from tqdm import tqdm


def get_uv_figax(MS):

    match MS:
        case str():
            MSlist = [MS]
        case Path():
            MSlist = [str(MS)]
        case list():
            MSlist = MS

    timeslots = [0, 0, 0]  # start, skip, end (default all)
    antToPlot = [-1]  # default all

    badval = 0.0
    xaxisvals0 = np.array([])
    yaxisvals0 = np.array([])
    xaxisvals1 = np.array([])
    yaxisvals1 = np.array([])
    xaxisvals2 = np.array([])
    yaxisvals2 = np.array([])
    xaxisvals3 = np.array([])
    yaxisvals3 = np.array([])
    xaxisvals4 = np.array([])
    yaxisvals4 = np.array([])
    xaxisvals5 = np.array([])
    yaxisvals5 = np.array([])
    savex0 = np.array([])
    savey0 = np.array([])
    savex1 = np.array([])
    savey1 = np.array([])
    savex2 = np.array([])
    savey2 = np.array([])
    savex3 = np.array([])
    savey3 = np.array([])
    savex4 = np.array([])
    savey4 = np.array([])
    savex5 = np.array([])
    savey5 = np.array([])

    numPlotted = 0
    ptcolor = 0
    for inputMS in MSlist:
        # open the main table and print some info about the MS
        print("Getting info for", inputMS)
        t = pt.table(inputMS, readonly=True, ack=False)
        tfreq = pt.table(t.getkeyword("SPECTRAL_WINDOW"), readonly=True, ack=False)
        ref_freq = tfreq.getcol("REF_FREQUENCY", nrow=1)[0]
        ch_freq = tfreq.getcol("CHAN_FREQ", nrow=1)[0]
        print("Reference frequency:\t%f MHz" % (ref_freq / 1.0e6))
        ref_wavelength = [2.99792458e8 / ref_freq]
        print("Reference wavelength:\t%f m" % (ref_wavelength[0]))
        firstTime = t.getcell("TIME", 0)
        lastTime = t.getcell("TIME", t.nrows() - 1)
        intTime = t.getcell("INTERVAL", 0)
        print("Integration time:\t%f sec" % (intTime))
        nTimeslots = (lastTime - firstTime) / intTime
        print("Number of timeslots:\t%d" % (nTimeslots))
        if timeslots[1] == 0:
            if nTimeslots >= 100:
                timeskip = int(nTimeslots / 100)
            else:
                timeskip = 1
        else:
            timeskip = int(timeslots[1])
        print("For each baseline, plotting one point every %d samples" % (timeskip))
        if timeslots[2] == 0:
            timeslots[2] = nTimeslots
        # open the antenna subtable
        tant = pt.table(t.getkeyword("ANTENNA"), readonly=True, ack=False)

        # Station names
        antList = tant.getcol("NAME")
        if len(antToPlot) == 1 and antToPlot[0] == -1:
            antToPlot = list(range(len(antList)))
        print("Station list (only starred stations will be plotted):")
        for i in range(len(antList)):
            star = " "
            if i in antToPlot:
                star = "*"
            print("%s %2d\t%s" % (star, i, antList[i]))

        # select by time from the beginning, and only use specified antennas
        tsel = t.query(
            "TIME >= %f AND TIME <= %f AND ANTENNA1 IN %s AND ANTENNA2 IN %s"
            % (
                firstTime + timeslots[0] * intTime,
                firstTime + timeslots[2] * intTime,
                str(antToPlot),
                str(antToPlot),
            ),
            columns="ANTENNA1,ANTENNA2,UVW",
        )

        # Now we loop through the baselines
        i = 0
        nb = (len(antToPlot) * (len(antToPlot) - 1)) / 2
        print("Reading uvw for %d baselines: %04d/%04d" % (nb, i, nb))

        for tpart in tqdm(tsel.iter(["ANTENNA1", "ANTENNA2"]), total=nb):
            ant1 = tpart.getcell("ANTENNA1", 0)
            ant2 = tpart.getcell("ANTENNA2", 0)
            if ant1 not in antToPlot or ant2 not in antToPlot:
                continue
            if ant1 == ant2:
                continue
            i += 1

            # Get the values to plot
            uvw = tpart.getcol("UVW", rowincr=timeskip)
            if numPlotted == 0:
                savex0 = np.append(savex0, [uvw[:, 0], -uvw[:, 0]])
                savey0 = np.append(savey0, [uvw[:, 1], -uvw[:, 1]])
                savex1 = np.append(savex1, [uvw[:, 0], -uvw[:, 0]])
                savey1 = np.append(savey1, [uvw[:, 1], -uvw[:, 1]])
                savex2 = np.append(savex2, [uvw[:, 0], -uvw[:, 0]])
                savey2 = np.append(savey2, [uvw[:, 1], -uvw[:, 1]])
                savex3 = np.append(savex3, [uvw[:, 0], -uvw[:, 0]])
                savey3 = np.append(savey3, [uvw[:, 1], -uvw[:, 1]])
                savex4 = np.append(savex4, [uvw[:, 0], -uvw[:, 0]])
                savey4 = np.append(savey4, [uvw[:, 1], -uvw[:, 1]])
                savex5 = np.append(savex5, [uvw[:, 0], -uvw[:, 0]])
                savey5 = np.append(savey5, [uvw[:, 1], -uvw[:, 1]])

            if ptcolor == 0:
                xaxisvals0 = np.append(xaxisvals0, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals0 = np.append(yaxisvals0, [uvw[:, 1], -uvw[:, 1]])
            elif ptcolor == 1:
                xaxisvals1 = np.append(xaxisvals1, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals1 = np.append(yaxisvals1, [uvw[:, 1], -uvw[:, 1]])
            elif ptcolor == 2:
                xaxisvals2 = np.append(xaxisvals2, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals2 = np.append(yaxisvals2, [uvw[:, 1], -uvw[:, 1]])
            elif ptcolor == 3:
                xaxisvals3 = np.append(xaxisvals3, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals3 = np.append(yaxisvals3, [uvw[:, 1], -uvw[:, 1]])
            elif ptcolor == 4:
                xaxisvals4 = np.append(xaxisvals4, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals4 = np.append(yaxisvals4, [uvw[:, 1], -uvw[:, 1]])
            elif ptcolor == 5:
                xaxisvals5 = np.append(xaxisvals5, [uvw[:, 0], -uvw[:, 0]])
                yaxisvals5 = np.append(yaxisvals5, [uvw[:, 1], -uvw[:, 1]])

        sys.stdout.write(" Done!\n")
        numPlotted += 1

    print("Plotting uv points ...")
    import matplotlib as mpl
    import matplotlib.pyplot as plt

    fig, ax = plt.subplots(nrows=1, figsize=(6, 6), sharex=True)
    fig.subplots_adjust(hspace=0)

    tmpvals0 = np.sqrt(xaxisvals0**2 + yaxisvals0**2)
    tmpvals1 = np.sqrt(xaxisvals1**2 + yaxisvals1**2)
    tmpvals2 = np.sqrt(xaxisvals2**2 + yaxisvals2**2)
    tmpvals3 = np.sqrt(xaxisvals3**2 + yaxisvals3**2)
    tmpvals4 = np.sqrt(xaxisvals4**2 + yaxisvals4**2)
    tmpvals5 = np.sqrt(xaxisvals5**2 + yaxisvals5**2)

    # Plot the data
    ax.set_xlabel("u [m]")
    ax.set_ylabel("v [m]")

    ax.plot(
        xaxisvals0[tmpvals0 != badval], yaxisvals0[tmpvals0 != badval], ",k", alpha=0.2
    )
    ax.plot(
        xaxisvals1[tmpvals1 != badval], yaxisvals1[tmpvals1 != badval], ",r", alpha=0.2
    )
    ax.plot(
        xaxisvals2[tmpvals2 != badval], yaxisvals2[tmpvals2 != badval], ",b", alpha=0.2
    )
    ax.plot(
        xaxisvals3[tmpvals3 != badval], yaxisvals3[tmpvals3 != badval], ",g", alpha=0.2
    )
    ax.plot(
        xaxisvals4[tmpvals4 != badval], yaxisvals4[tmpvals4 != badval], ",y", alpha=0.2
    )
    ax.plot(
        xaxisvals5[tmpvals5 != badval], yaxisvals5[tmpvals5 != badval], ",c", alpha=0.2
    )

    return fig, ax

# %%
MS_parent = Path("/home/bbd0953/diffusion/sky_maps/test_map_80/synthms")
MS_file = MS_parent / "test_map_80_t201811301614_SBH225.MS"

fig, ax = get_uv_figax(MS_file)

# %% [markdown]
# # Simulate pointing position for mock observation

# %%
import matplotlib.pyplot as plt
import numpy as np

from astropy.visualization import astropy_mpl_style, quantity_support
import astropy.units as u
from astropy.coordinates import AltAz, EarthLocation, SkyCoord
from astropy.time import Time

# Target: RA = 180 deg, DEC = 45 deg
# Starting time: 2018-06-30 11:00:02.003

# Set up matplotlib style for quantity support
# plt.style.use(astropy_mpl_style)
quantity_support()

target = SkyCoord(0.031250, 23.395251, unit="deg")
location = EarthLocation.of_site("LOFAR")

utcoffset = 0 * u.hour  # CEST = UTC+2
t_start = Time("2018-11-30 15:14:39.006") - utcoffset  # Local time to UTC
t_deltas = np.linspace(0, 8, 100) * u.hour
target_frame = AltAz(obstime=t_start + t_deltas, location=location)
altaz = target.transform_to(target_frame)

# %matplotlib inline
fig, ax = plt.subplots(figsize=(9, 6))
scat = ax.scatter(
    t_deltas, altaz.alt, label="Target", c=altaz.az.value, cmap="viridis", lw=0, s=8
)
ax.set_xlabel(f"Time since {t_start.datetime}")
ax.set_ylabel("Altitude [deg]")
ax.set_title("Altitude of target over time")
ax.legend()
plt.colorbar(scat).set_label("Azimuth [deg]")
fig.show()

# %%
Time("2018-11-30 15:14:39.006").mjd * 3600 * 24

# %% [markdown]
# # Compare Size Distributions

# %%
# Read 5deg simulation data
from astropy.table import Table

map_name = "map_5deg_v1"
trecs_cat_file = (
    paths.SKY_MAP_PARENT / map_name / "trecs/catalogue_continuum_wrapped.fits"
)
trecs_df = Table.read(trecs_cat_file, hdu=1, unit_parse_strict="silent").to_pandas()

# %%
# Apply SS-AGn cut
SS_AGN_flag = trecs_df["RadioClass"] == 6
SS_AGN_df = trecs_df[SS_AGN_flag]

# Apply size cutoff
size_cutoff = 0  # arcsec
cutoff_flag = SS_AGN_df["size"] >= size_cutoff
SS_AGN_df_cutoff = SS_AGN_df[cutoff_flag]

print(len(SS_AGN_df_cutoff))

# %%
# Read mask metadata from prototypes
import utils.paths as paths
import pandas as pd

mask_metadata = pd.read_hdf(paths.LOFAR_SUBSETS["prototypes"], key="mask_metadata")

# Apply size cutoff
cutoff_flag = mask_metadata["feret_diameter_max"] * 1.5 >= size_cutoff
mask_metadata_cut = mask_metadata[cutoff_flag]

# Select random rows from mask metadata to have same number of sources as SS AGN
mask_metadata_sample = mask_metadata_cut.sample(n=len(SS_AGN_df_cutoff))
mask_metadata_sample = mask_metadata_cut

# %%
# Load catalog instead
ptypes_cat = pd.read_hdf(paths.LOFAR_SUBSETS["prototypes"], key="catalog")

# Apply size cutoff
cutoff_flag = ptypes_cat["LAS"] * 1.5 >= size_cutoff
ptypes_cat_cut = ptypes_cat[cutoff_flag]

# Select random rows from mask metadata to have same number of sources as SS AGN
ptypes_cat_sample = ptypes_cat_cut.sample(n=len(SS_AGN_df_cutoff))
ptypes_cat_sample = ptypes_cat_cut

# %%
# Finally, read resolved LoTSS catalogue
resolved_df = pd.read_csv(paths.LOFAR_RES_CAT)

# Apply size cutoff
cutoff_flag = resolved_df["LAS"] >= size_cutoff
resolved_df_cut = resolved_df[cutoff_flag]

# Apply luminosity AGN cut
# Number of sources above and below 10^25 W/Hz in prototypes set
lum_threshold = 10**25
lum_cut_flag = resolved_df_cut["L_144"] > lum_threshold
resolved_df_cut = resolved_df_cut[lum_cut_flag]


# Select random rows from resolved LoTSS catalogue to have same number of sources as SS AGN
resolved_df_sample = resolved_df_cut.sample(n=len(SS_AGN_df_cutoff))
resolved_df_sample = resolved_df_cut

# %%
# Compare distributions of size
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(8, 6), dpi=150)

bins = np.logspace(0, 3, 100)

# For all plots:
kwargs = {
    "bins": np.logspace(0, 3, 100),
    # "bins": np.linspace(0.1, 250, 250),
    "histtype": "step",
    "log": True,
    "density": True,
    "alpha": 0.3,
}

ax.hist(
    resolved_df_sample["LAS"],
    label="Resolved LoTSS (AGN Cut)",
    **kwargs,
)
ax.hist(
    SS_AGN_df_cutoff["size"], label="TRECS SS-AGN", **kwargs,
)
ax.hist(
    mask_metadata_sample["feret_diameter_max"] * 1.5,
    label="Training Data Mask Size",
    **kwargs,
)
ax.hist(
    ptypes_cat["LAS"],
    label="Training Data LAS",
    **kwargs,
)

ax.set_xlabel("Size (arcsec)")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)

ax.set_yscale("log")
ax.set_xscale('log')
ax.set_title(f"Cut at {size_cutoff} arcsec")

# %matplotlib inline
fig.show()

# %% [markdown]
# # MapMaker implementation

# %%
import utils.paths as paths

reload(paths)

import maps.map_maker as mapmaker

reload(mapmaker)

trecs_cat_file = (
    paths.BASE_PARENT / "trecs_output/5deg/catalogue_continuum_wrapped.fits"
)

# Create a map
mm = mapmaker.MapMaker(
    map_size_deg=5,
    model_name="Prototypes_Model_SizeCond",
    trecs_cat_file=trecs_cat_file,
    dset="prototypes",
    sampler_settings={"n_devices": 2},
)

# %%
mm.make_map()

# %%
import utils.paths as paths

reload(paths)

mm.save("map_5deg_max80")

# %%
import maps.map_maker as mapmaker

reload(mapmaker)
mm_read = mapmaker.MapMaker.load("map_5deg_max80")

# %%
mm_read.file_name

# %%
import maps.map_utils

reload(maps.map_utils)
mm_read.save_to_fits(override=True)

# %%
mm_read.make_mask()

# %%
# %matplotlib widget
mm_read.plot_map()

# %%
mm_read.map_array.shape

# %%
# %matplotlib inline
plt.hist(mm_read.ext_df['context_size'].values, bins=10)
plt.show()

# %%
import plotting.image_plots

reload(plotting.image_plots)

from plotting.image_plots import metric_peek
import np as np

metric_peek(
    mm_read.ext_df["context_size"].values,
    np.linspace(60, 120, 7),
    mm_read.ext_data["images"],
    # masks=mm_read.ext_data['masks'],
    fmt_str="{:.2f}",
    metric_name="Source Size (px)",
)

# %%
from astropy.table import Table

trecs_file = "/home/bbd0953/diffusion/trecs_output/catalogue_continuum_wrapped.fits"
trecs_df = Table.read(trecs_file, hdu=1, unit_parse_strict="silent").to_pandas()

# %%
# Plot input size distribution vs. TRECS SS-AGN size distribution

AGN_flag = trecs_df["RadioClass"] == 6
AGN_df = trecs_df[AGN_flag]

fig, ax = plt.subplots(1, 1, figsize=(10, 6))

ax.hist(
    AGN_df["size"],
    bins=150,
    alpha=0.8,
    label="TRECS SS-AGN",
    histtype="step",
    density=True,
)
size_px, bins = mm_read.model_size_distribution
ax.stairs(size_px * 1.5, bins, label="Training Data", alpha=0.8)

ax.set_xlabel("Size (arcsec)")
ax.set_ylabel("Count")
ax.set_yscale("log")
ax.set_xlim(left=-10, right=250)
ax.grid(alpha=0.3)
ax.legend()

fig.show()

# %%
from plotting.image_plots import plot_image_grid
from data.transforms import minmax_scale
import np as np

n = 18
idxs = np.random.choice(len(mm_read.comp_images), n, replace=False)
imgs = [minmax_scale(mm_read.comp_images[i]) for i in idxs]

plot_image_grid(imgs, n_cols=6)

# %% [markdown]
# ## Closer look at mask generation

# %%
i = 363
img = mm_read.ext_data["images"][i]
dist_mask = mm_read.ext_data["masks"][i]
plt.imshow(img)
plt.contour(dist_mask, levels=[0.5], colors="r")

# %%
plt.imshow(img * (1 - dist_mask))

# %%
from data.segment import *
from scipy.ndimage import (
    binary_fill_holes,
    binary_closing,
    binary_opening,
    binary_dilation,
    binary_erosion,
)


def get_sample_mask(img, expand=False, dilate=0):
    cmask = circular_mask(img.shape)
    safe_background = img[~cmask].flatten()
    source_mask = img > np.mean(safe_background) + 3 * safe_background.std()

    # Iteratively expand to 1 sigma
    if expand:
        i = 0
        while i < 10:
            background = img[~source_mask].flatten()
            exp_mask = img > np.mean(background) + 1.5 * background.std()
            if np.all(exp_mask == source_mask):
                break
            source_mask = expand_islands(source_mask, exp_mask)
            i += 1

    source_mask = smooth_mask(source_mask)

    if dilate:
        source_mask = binary_dilation(source_mask, iterations=dilate)

    return source_mask.astype(int)

# %%
cmask = circular_mask(img.shape)

plt.imshow(img * (1 - cmask))

# %%
from data.datasets import LOFARPrototypesDataset

dset = LOFARPrototypesDataset("prototypes", img_size=80)

# %%
plt.hist(dset.mask_sizes)

# %%
metric_peek(
    dset.mask_sizes,
    np.linspace(80, 81, 1),
    dset.data,
    masks=dset.masks,
    n_examples=20,
    fmt_str="{:.2f}",
    metric_name="Mask Size",
)

# %%
# %matplotlib widget
fig, ax = plt.subplots(1, 1)
ax.scatter(dset.mask_sizes/2, dset.mask_metadata['Model_Radius'])
ax.grid(alpha=0.3)
ax.set_xlabel("Mask Size / 2")
ax.set_ylabel("Model Radius")
fig.show()
# %matplotlib inline

# %% [markdown]
# # LoTSS Catalog statistics

# %%
# LAS distribution in LOTSS-DR2 resolved catalog
import pandas as pd
from utils.paths import LOFAR_RES_CAT

# Load catalog
cat_df = pd.read_csv(LOFAR_RES_CAT)

# %%
import data.datasets as dsts
import utils.paths as paths

# Load cutouts
cutouts_path = paths.CUTOUTS_DIR / "cutouts_200p_optC.hdf5"
cutouts = dsts.CutoutsDataset(cutouts_path)

# %%
reload(dsts)
# Load prototypes ptypes_cut
ptypes = dsts.LOFARPrototypesDataset("prototypes", img_size=80, load_catalog=True)

# %%
samples = dsts.SamplesDataset("Prototypes_Model")

# %%
from data.segment import get_sample_mask

samples.masks = [get_sample_mask(img.squeeze().np()) for img in samples.data]

# %%
from tqdm import tqdm
from skimage.measure import regionprops

samples_region_props = [
    regionprops(mask.astype(int))[0] for mask in tqdm(samples.masks)
]
samples.mask_sizes = np.array([rp.feret_diameter_max for rp in samples_region_props])

# %% [markdown]
# ## Plotting

# %%
# LAS distributions
import np as np

fig, ax = plt.subplots(1, 1, figsize=(10, 6))

bins = 100  # np.linspace(0, 20, 101)
ax.hist(
    cutouts.catalog["LAS"], bins=bins, label="Cutouts", density=True, histtype="step"
)
ax.hist(
    ptypes.catalog["LAS"], bins=bins, label="Prototypes", density=True, histtype="step"
)

ax.set_title("LAS distribution in LOTSS-DR2 resolved catalog")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Count")

ax.legend()
ax.grid(alpha=0.3)

ax.set_yscale("log")

fig.show()

# %%
# Flux distributions
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

bins = 100  # np.linspace(0, 20, 101)
ax.hist(
    cutouts.catalog["Total_flux"],
    bins=bins,
    label="Cutouts",
    density=True,
    histtype="step",
)
ax.hist(
    ptypes.catalog["Total_flux"],
    bins=bins,
    label="Prototypes",
    density=True,
    histtype="step",
)

ax.set_title("Total flux distribution in LOTSS-DR2 resolved catalog")
ax.set_xlabel("Total flux [Jy]")
ax.set_ylabel("Count")

ax.legend()
ax.grid(alpha=0.3)

ax.set_yscale("log")

fig.show()

# %%
def adaptive_binning(x, min_points_per_bin, min_bin_width):
    # Sort the data by x
    x_sorted = np.sort(x)

    bin_edges = []
    bin_start = 0

    while bin_start < len(x_sorted):
        bin_end = bin_start + min_points_per_bin
        while bin_end < len(x_sorted) and (
            x_sorted[bin_end] - x_sorted[bin_start] < min_bin_width
        ):
            bin_end += 1

        if bin_end >= len(x_sorted):
            bin_end = len(x_sorted)

        bin_edges.append(x_sorted[bin_start])
        bin_start = bin_end

    bin_edges.append(x_sorted[-1])  # Ensure the last edge is included

    return bin_edges


def adaptive_binning_log(x, min_points_per_bin, min_bin_width):
    # Transform data to log-space
    log_x = np.log10(x)

    # Sort the data by log_x
    log_x_sorted = np.sort(log_x)

    bin_edges_log = []
    bin_start = 0

    while bin_start < len(log_x_sorted):
        bin_end = bin_start + min_points_per_bin

        # If value is zero, log is -inf, so we need to skip it
        if log_x_sorted[bin_start] == -np.inf:
            bin_start += 1
            continue

        while bin_end < len(log_x_sorted) and (
            log_x_sorted[bin_end] - log_x_sorted[bin_start] < min_bin_width
        ):
            bin_end += 1

        if bin_end >= len(log_x_sorted):
            bin_end = len(log_x_sorted)

        bin_edges_log.append(log_x_sorted[bin_start])
        bin_start = bin_end

    bin_edges_log.append(log_x_sorted[-1])  # Ensure the last edge is included

    # Transform bin edges back to the original space
    bin_edges = 10 ** np.array(bin_edges_log)

    return bin_edges

# %%
# LAS vs Flux
from scipy.stats import binned_statistic

fig, axs = plt.subplots(2, 1, figsize=(10, 12), sharex=True)

# Scatter plot of LAS vs. total flux
ax = axs[0]

kwargs = {"s": 5, "alpha": 0.5}

ax.scatter(
    cutouts.catalog["LAS"], cutouts.catalog["Total_flux"], label="Cutouts", **kwargs
)
ax.scatter(
    ptypes.catalog["LAS"], ptypes.catalog["Total_flux"], label="Prototypes", **kwargs
)

ax.set_title("LAS vs. Total flux in LOTSS-DR2 resolved catalog")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Total flux [Jy]")
ax.legend()
ax.grid(alpha=0.3)

ax.set_xscale("log")
ax.set_yscale("log")

# Plot of median LAS vs. total flux
ax = axs[1]

# Cutouts
bin_edges = adaptive_binning_log(cutouts.catalog["LAS"], 50, 0.2)
bin_medians = binned_statistic(
    cutouts.catalog["LAS"],
    cutouts.catalog["Total_flux"],
    statistic="median",
    bins=bin_edges,
)[0]
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])
ax.errorbar(
    bin_centers,
    bin_medians,
    xerr=0.5 * (bin_edges[1:] - bin_edges[:-1]),
    fmt="o",
    label="Cutouts",
)

# Prototypes
bin_edges = adaptive_binning_log(ptypes.catalog["LAS"], 50, 0.2)
bin_medians = binned_statistic(
    ptypes.catalog["LAS"],
    ptypes.catalog["Total_flux"],
    statistic="median",
    bins=bin_edges,
)[0]
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])
ax.errorbar(
    bin_centers,
    bin_medians,
    xerr=0.5 * (bin_edges[1:] - bin_edges[:-1]),
    fmt="o",
    label="Prototypes",
)

ax.set_title("Median LAS vs. Total flux in LOTSS-DR2 resolved catalog")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Total flux [Jy]")
ax.legend()

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)

fig.show()

# %%
# LAS vs Luminosity
fig, axs = plt.subplots(2, 1, figsize=(10, 12), sharex=True)

# Scatter plot of LAS vs. total flux
ax = axs[0]

kwargs = {"s": 5, "alpha": 0.5}

ax.scatter(cutouts.catalog["LAS"], cutouts.catalog["L_144"], label="Cutouts", **kwargs)
ax.scatter(ptypes.catalog["LAS"], ptypes.catalog["L_144"], label="Prototypes", **kwargs)

ax.set_title("LAS vs. Total flux in LOTSS-DR2 resolved catalog")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Total flux [Jy]")
ax.legend()
ax.grid(alpha=0.3)

ax.set_xscale("log")
ax.set_yscale("log")

# Plot of median LAS vs. total flux
ax = axs[1]

# Cutouts
bin_edges = adaptive_binning_log(cutouts.catalog["LAS"], 50, 0.2)
bin_medians = binned_statistic(
    cutouts.catalog["LAS"], cutouts.catalog["L_144"], statistic="median", bins=bin_edges
)[0]
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])
ax.errorbar(
    bin_centers,
    bin_medians,
    xerr=0.5 * (bin_edges[1:] - bin_edges[:-1]),
    fmt="o",
    label="Cutouts",
)

# Prototypes
bin_edges = adaptive_binning_log(ptypes.catalog["LAS"], 50, 0.2)
bin_medians = binned_statistic(
    ptypes.catalog["LAS"], ptypes.catalog["L_144"], statistic="median", bins=bin_edges
)[0]
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])
ax.errorbar(
    bin_centers,
    bin_medians,
    xerr=0.5 * (bin_edges[1:] - bin_edges[:-1]),
    fmt="o",
    label="Prototypes",
)

ax.set_title("Median LAS vs. Total flux in LOTSS-DR2 resolved catalog")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Total flux [Jy]")
ax.legend()

ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(alpha=0.3)

fig.show()

# %%
# Luminosity distributions
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

bins = np.logspace(12, 30, 101)
ax.hist(
    cutouts.catalog["L_144"], bins=bins, label="Cutouts", density=False, histtype="step"
)
ax.hist(
    ptypes.catalog["L_144"],
    bins=bins,
    label="Prototypes",
    density=False,
    histtype="step",
)

ax.set_title("Luminosity distribution in LOTSS-DR2 resolved catalog")
ax.set_xlabel("Luminosity [W/Hz]")

# Vertical line at 10**25
ax.axvline(10**25, color="black", linestyle="--", label="10^25")

ax.legend()
ax.grid(alpha=0.3)

ax.set_xscale("log")
ax.set_yscale("log")

fig.show()

# %% [markdown]
# ## AGN Luminosity Cut

# %%
# Number of sources above and below 10^25 W/Hz in prototypes set
lum_threshold = 10**25
ptypes_cut_flag = ptypes.catalog["L_144"] > lum_threshold

print(
    f"Number of sources above {lum_threshold:.0e} W/Hz: {ptypes_cut_flag.sum()} ({ptypes_cut_flag.sum() / len(ptypes.catalog) * 100:.2f}%)"
)
print(
    f"Number of sources below {lum_threshold:.0e} W/Hz: {(~ptypes_cut_flag).sum()} ({(~ptypes_cut_flag).sum() / len(ptypes.catalog) * 100:.2f}%)"
)

# Number of sources above and below 10^25 W/Hz in cutouts set
cutouts_cut_flag = cutouts.catalog["L_144"] > lum_threshold

print(
    f"Number of sources above {lum_threshold:.0e} W/Hz: {cutouts_cut_flag.sum()} ({cutouts_cut_flag.sum() / len(cutouts.catalog) * 100:.2f}%)"
)
print(
    f"Number of sources below {lum_threshold:.0e} W/Hz: {(~cutouts_cut_flag).sum()} ({(~cutouts_cut_flag).sum() / len(cutouts.catalog) * 100:.2f}%)"
)

# %%
ptypes_cut = ptypes.index_sliced(ptypes_cut_flag.values)
cutouts_cut = cutouts.index_sliced(cutouts_cut_flag.values)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

ax.hist(
    cutouts_cut.catalog["LAS"],
    bins=100,
    density=False,
    histtype="step",
    label="Cutouts",
)
ax.hist(
    ptypes_cut.catalog["LAS"],
    bins=100,
    density=False,
    histtype="step",
    label="Prototypes",
)

# ax.set_xscale('log')
ax.set_yscale("log")

ax.set_title("LAS distribution in LOTSS-DR2 resolved catalog (L > 10^25 W/Hz)")
ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)
ax.legend()
fig.show()

# %%
cutout_name_dict = {name: i for i, name in enumerate(cutouts_cut.names)}
slice_idxs = [cutout_name_dict[name] for name in ptypes_cut.names]
ptype_cutouts = cutouts_cut.index_sliced(np.array(slice_idxs))

# %%
from data.transforms import minmax_scale_batch

img_pairs = np.concatenate(
    (
        ptypes_cut.data.squeeze().np(),
        minmax_scale_batch(ptype_cutouts.data.squeeze()).np(),
    ),
    axis=2,
)

# %%
import plotting.image_plots

reload(plotting.image_plots)
from plotting.image_plots import metric_peek

metric_peek(
    ptypes_cut.catalog["LAS"].values,
    np.linspace(0, 500, 10),
    img_pairs,
    n_examples=15,
    metric_name="LAS (arsec)",
    fmt_str="{:.2f}",
)

# %%
import plotting.image_plots

reload(plotting.image_plots)
from plotting.image_plots import metric_peek

metric_peek(
    cutouts_cut.catalog["LAS"].values,
    np.linspace(0, 750, 10),
    cutouts_cut.data.squeeze().np(),
    metric_name="LAS (arsec)",
    fmt_str="{:.2f}",
)

# %% [markdown]
# ## Add mask size to dataset

# %%
from tqdm import tqdm
from skimage.measure import regionprops, regionprops_table

properties = (
    "num_pixels",
    "orientation",
    "feret_diameter_max",
)

region_props = [
    regionprops_table(
        m.np().astype(int),
        properties=properties,
    )
    for m in tqdm(ptypes.masks)
]

# %%
# Extract single entries from arrays
for d in region_props:
    for key in d:
        d[key] = d[key][0]

new_meta = pd.concat(
    [
        ptypes.mask_metadata,
        pd.DataFrame(region_props),
    ],
    axis=1,
)
new_meta

# %%
# Replace mask_metadata df in file with new_meta
import h5py

with h5py.File(ptypes.path, "r+") as f:
    del f["mask_metadata"]

new_meta.to_hdf(ptypes.path, key="mask_metadata", mode="a")

# %%
# Scatter plot size (in arcsec) vs LAS
# %matplotlib inline

fig, ax = plt.subplots(1, 1, figsize=(10, 6))

ax.scatter(
    ptypes.catalog["LAS"],
    ptypes.mask_metadata['feret_diameter_max'].values * 1.5,
    s=5,
    alpha=0.5,
    label="Prototypes",
)

# Plot identity and 1/2 identity
x = np.linspace(0, 500, 100)
ax.plot(x, x, "--", color="black", label="Identity", alpha=0.5)
# ax.plot(x, x / 2, "--", color="black", label="1/2 Identity", alpha=0.5)

ax.set_title("Size vs LAS for prototype dataset")

ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Mask Size [arcsec]")

ax.set_xlim(left=0, right=300)
ax.set_ylim(bottom=0, top=300)

ax.legend()
ax.grid(alpha=0.3)

fig.show()

# %%
las = ptypes.catalog["LAS"]
size = ptypes.mask_metadata["feret_diameter_max"].values * 1.5

nonzero_flag = las > 0
las = las[nonzero_flag]
size = size[nonzero_flag]

ratio = size / las

fig, axs = plt.subplots(3, 1, figsize=(10, 18))


ax = axs[0]
ax.scatter(
    las,
    size,
    s=5,
    alpha=0.5,
    label="Prototypes",
)

# Plot identity and 1/2 identity
x = np.linspace(0, 500, 100)
ax.plot(x, x, "--", color="black", label="Identity", alpha=0.5)
# ax.plot(x, x / 2, "--", color="black", label="1/2 Identity", alpha=0.5)

ax.set_title("Mask Size vs LAS for prototype dataset")

ax.set_xlabel("LAS [arcsec]")
ax.set_ylabel("Mask Size [arcsec]")

ax.set_xlim(left=0, right=300)
ax.set_ylim(bottom=0, top=300)

ax.legend()
ax.grid(alpha=0.3)

# Plot both distributions
ax = axs[1]
ax.hist(size, bins=250, density=True, histtype="step", label="Mask Size")
ax.hist(las, bins=750, density=True, histtype="step", label="LAS")

ax.set_title("Mask Size and LAS distributions for prototype dataset")
ax.set_xlabel("Size (arcsec)")
ax.set_ylabel("Count Density")
ax.grid(alpha=0.3)
ax.legend()

# ax.set_yscale('log')
ax.set_xlim(left=-0.1, right=500)


# Plot ratio distribution
ax = axs[2]
cts, bns, _ = ax.hist(ratio, bins=750, density=False, histtype="step")

# Vertical line at 0.5
ax.axvline(0.5, color="black", linestyle="--", label="0.5", alpha=0.5)

# Vertical line at count maximum
max_idx = np.argmax(cts)
max_val = (bns[max_idx] + bns[max_idx + 1]) / 2
ax.axvline(
    max_val, color="orange", linestyle="--", label=f"Max at {max_val:.2f}", alpha=0.5
)

ax.set_title("Mask Size/LAS ratio for prototype dataset")
ax.set_xlabel("Mask Size/LAS")
ax.set_ylabel("Count")
ax.grid(alpha=0.3)
ax.legend()

# ax.set_yscale('log')
ax.set_xlim(left=-0.01, right=3)
fig.show()

# %%
# Box-cox transformation on size distribution
from scipy.stats import boxcox, rv_histogram
from scipy.special import inv_boxcox

size_bc, lambda_ = boxcox(size)

mean, std = size_bc.mean(), size_bc.std()

size_bc_standardized = (size_bc - mean) / std

fig, axs = plt.subplots(2, 1, figsize=(10, 12))

ax = axs[0]
ax.hist(
    size_bc_standardized,
    bins=100,
    density=True,
    histtype="step",
    label="Mask Size (Box-Cox)",
)

# Plot gaussian to compare
x = np.linspace(-3, 3, 100)
gaussian = np.exp(-0.5 * x**2) / np.sqrt(2 * np.pi)
ax.plot(x, gaussian, label="Gaussian", alpha=0.5)

ax.set_xlabel("Transformed Size")
ax.set_ylabel("Count Density")
ax.grid(alpha=0.3)
ax.legend()

ax = axs[1]
ax.hist(size, bins=250, density=True, histtype="step", label="Mask Size")
ax.hist(
    samples.mask_sizes * 1.5,
    bins=250,
    density=True,
    histtype="step",
    label="Sample Mask Size",
)

# Plot inverse-boxcox of randoms sampled from rv_histogram
rv_bins = 250
hist = np.histogram(size_bc_standardized, bins=250)
rv = rv_histogram(hist)
rv_randoms = rv.rvs(size=100000) * std + mean
inv_rv_randoms = inv_boxcox(rv_randoms, lambda_)
ax.hist(
    inv_rv_randoms,
    bins=rv_bins,
    density=True,
    histtype="step",
    label="Inverse Box-Cox of Mask Size",
    alpha=0.5,
)

# Plot inverse-boxcox of gaussian
if False:
    randoms = np.random.normal(0, 1, 10000) * std + mean
    inv_randoms = inv_boxcox(randoms, lambda_)
    ax.hist(
        inv_randoms,
        bins=100,
        density=True,
        histtype="step",
        label="Inverse Box-Cox of Gaussian",
        alpha=0.5,
    )

ax.set_xlabel("Size")
ax.set_ylabel("Count Density")
ax.grid(alpha=0.3)
ax.legend()

ax.set_yscale("log")

fig.show()

# %% [markdown]
# # T-RECS Catalogs

# %%
from astropy.io import fits
from astropy.table import Table, vstack
import pandas as pd
import utils.paths as paths

trecs_cat_file = paths.BASE_PARENT / "trecs_output/catalogue_continuum_wrapped.fits"
tbl = Table.read(trecs_cat_file, hdu=1)
trecs_df = tbl.to_pandas()

# Classes:
# 1 - 3: SFGs
# 4: FSRQ, 5: BL-Lac, 6: SS-AGN
class_flag = trecs_df["RadioClass"].values
class_df_dict = {
    "SFG": trecs_df[class_flag < 4],
    "FSRQ_&_BL-Lac": trecs_df[(class_flag > 3) & (class_flag < 6)],
    "SS-AGN": trecs_df[class_flag == 6],
}

# %%
# LAS distribution in LOTSS-DR2 resolved catalog
import pandas as pd
from utils.paths import LOFAR_RES_CAT

# Load catalog
cat_df = pd.read_csv(LOFAR_RES_CAT)

# AGN Cut
lum_threshold = 10**25
AGN_cut_flag = cat_df["L_144"] > lum_threshold

cat_df_AGN = cat_df[AGN_cut_flag]

# %% [markdown]
# ## Plot some distributions

# %%
import np as np

fig, ax = plt.subplots(1, 1, figsize=(8, 6), tight_layout=True)

bins = np.linspace(0, 1000, 101)

kwargs = {
    "bins": bins,
    "log": True,
    "density": True,
    "histtype": "step",
}
# ax.hist(trecs_df["size"], label="T-RECS: All", **kwargs)
ax.hist(class_df_dict["SS-AGN"]["size"], label="T-RECS: SS-AGN", **kwargs)
# ax.hist(cat_df["LAS"], label='LoTSS-DR2 resolved: All', **kwargs)
ax.hist(cat_df_AGN["LAS"], label="LoTSS-DR2 resolved: AGN Cut", **kwargs)

ax.grid(alpha=0.3)
ax.set_xlabel("Size (arcsec)")
ax.set_ylabel("Norm. Counts")
ax.legend()

fig.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6), tight_layout=True)

ax.scatter(AGN_df_res["size"], AGN_df_res["I144"], s=5)
ax.set_xscale("log")
ax.set_yscale("log")

ax.grid(alpha=0.3)
ax.set_xlabel("Size (arcsec)")
ax.set_ylabel("I144 (mJy)")

# %%
# Scatter plot of the AGNs based on latitude and longitude coords
fig, ax = plt.subplots(1, 1, figsize=(10, 10), tight_layout=True)

colors = ["lightgray", "blue", "fuchsia"]
for (name, df), clr in zip(class_df_dict.items(), colors):
    ax.scatter(
        df["x_coord"], df["y_coord"], label=name.replace("_", " "), s=5, color=clr
    )

ax.set_xlabel("Longitude (deg)")
ax.set_ylabel("Latitude (deg)")
ax.grid(alpha=0.2)
ax.legend(loc="upper center", ncols=3)

fig.show()

# %%
# Size
px_size = 1.5  # arcsec
px_per_deg = 3600 / px_size
px_per_deg

# %% [markdown]
# ## Rescaling of Source Images

# %%
from data.datasets import SamplesDataset

ptypes_cut = SamplesDataset("Prototypes_Model")

# %%
ptypes_cut.data.shape

# %%
from tqdm import tqdm
import data.segment

reload(data.segment)
from data.segment import get_sample_mask
from skimage.measure import regionprops

# Analyse the dataset
ptypes_cut.masks = np.zeros_like(ptypes_cut.data.squeeze())
ptypes_cut.sizes_px = np.zeros(len(ptypes_cut))
ptypes_cut.region_props = []
for i in tqdm(range(len(ptypes_cut))):
    img = ptypes_cut[i].np().squeeze()
    dist_mask = get_sample_mask(img)
    props = regionprops(dist_mask.astype(int))[0]
    ptypes_cut.masks[i] = dist_mask
    ptypes_cut.sizes_px[i] = props.feret_diameter_max
    ptypes_cut.region_props.append(props)

# %%
ptypes_cut.plot_image_grid()

# %%
i = 4792
img = ptypes_cut[i].np().squeeze()
dist_mask = ptypes_cut.masks[i]
props = ptypes_cut.region_props[i]

plt.imshow(img[props.slice])

# %%
# Compare distributions
from analysis.stats_utils import norm
from plotting.plot_utils import add_distribution_plot

fig, ax = plt.subplots(1, 1, figsize=(8, 6), tight_layout=True)

bins = np.linspace(0, 150, 76)

c_smpl, _ = np.histogram(ptypes_cut.sizes_px, bins=bins)
c_AGN, _ = np.histogram(AGN_df_res["size"] / 1.5, bins=bins)
c_AGN_sc, _ = np.histogram(AGN_df_res["size"] * AGN_df_res["Rs"] / 1.5, bins=bins)

add_distribution_plot(c_smpl, bins, ax, label="Samples", color="blue")
add_distribution_plot(c_AGN, bins, ax, label="AGN", color="red")

ax.grid(alpha=0.3)
ax.set_xlabel("Size (px)")
ax.set_ylabel("Number of sources")
ax.legend()

fig.show()

# %%
# LAS distribution in LOTSS-DR2 resolved catalog
import pandas as pd
from utils.paths import LOFAR_RES_CAT

cat_df = pd.read_csv(LOFAR_RES_CAT)

# %%
zero_flag = cat_df.LAS == 0
cat_df_zero = cat_df[zero_flag]

cat_df_zero[["LAS", "LAS_from"]]

# %%
cat_df.LAS.hist(bins=np.linspace(0, 1, 11), log=True)

# %%
img = ptypes_cut[np.random.randint(0, len(ptypes_cut))].np().squeeze()
dist_mask = get_sample_mask(img)

fig, axs = plt.subplots(1, 2, figsize=(12, 6), tight_layout=True)

axs[0].imshow(img)

axs[1].imshow(dist_mask * img)
axs[1].contour(dist_mask, levels=[0.5], colors="r")

# %%
from skimage.measure import regionprops

props = regionprops(dist_mask.astype(int))[0]
sample_size_px = props["feret_diameter_max"]
sample_size_px

# %%
source = AGN_df_res.iloc[np.random.randint(0, len(AGN_df_res))]
target_size_px = source["size"] / 1.5  # 1.5 arcsec per pixel
target_size_px

# %%
from skimage.transform import rescale
from scipy.ndimage import gaussian_filter

img_rescaled = rescale(
    dist_mask * img, target_size_px / sample_size_px, anti_aliasing=False
)
mask_rescaled = img_rescaled > 0

fig, axs = plt.subplots(1, 2, figsize=(10, 5), tight_layout=True)

ax = axs[0]
ax.imshow(img_rescaled)
ax.contour(mask_rescaled, levels=[0.5], colors="r")

ax = axs[1]
ax.imshow(gaussian_filter(img_rescaled, 4 / 2.355))

# %%
props_rescaled = regionprops(mask_rescaled.astype(int))[0]
rescaled_size_px = props_rescaled["feret_diameter_max"]
rescaled_size_px

# %% [markdown]
# ## Reproject Mosaics

# %%
header["NAXIS2"] * header["CDELT2"]

# %%
header

# %%
from plotting.map_plots import plot_sky_map

plot_sky_map(img, wcs=wcs)

# %%
from reproject.mosaicking import find_optimal_celestial_wcs

map_list = [get_image(path) for path in list(mosaic_dict.values())[:10]]

wcs_out, shape_out = find_optimal_celestial_wcs(map_list)

# %%
from reproject import reproject_interp
from reproject.mosaicking import reproject_and_coadd

array, footprint = reproject_and_coadd(
    map_list, wcs_out, shape_out=shape_out, reproject_function=reproject_interp
)

# %%
import matplotlib.pyplot as plt
import numpy as np

plot_sky_map(
    array, wcs=wcs_out, scale_fn=lambda x: np.tanh(x * (x > 0).astype(int) * 500)
)

# %%
plot_sky_map(footprint, wcs=wcs_out)
